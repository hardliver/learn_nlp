# %% [markdown]
# ### 基于Tensorflow实现word2vec

# %%
import collections
import os
import random
import urllib
import zipfile

import numpy as np
import tensorflow as tf

# %%
tf.get_logger().setLevel('ERROR')

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# 训练参数
learning_rate = 0.1
batch_size = 128
num_steps = 3000000
display_step = 10000
eval_step = 200000

# 测试样例
eval_words = ['nine', 'of', 'going', 'hardware', 'american', 'britain']

# Word2Vec 参数
embedding_size = 200 # 词向量维度
max_vocabulary_size = 50000 # 语料库词语数
min_occurrence = 10 # 最小词频
skip_window = 3 # 左右窗口大小
num_skips = 2 # 一次制作多少个输入输出对
num_sampled = 64 # 负采样

# %%
# 加载训练数据，其实什么数据都行
data_path = 'text8.zip'
with zipfile.ZipFile(data_path) as f:
    text_words = f.read(f.namelist()[0]).lower().split()

# %%
len(text_words)
# Out:
# 17005207

# %%
# 创建一个计数器，计算每个词出现了多少次
count = [('UNK', -1)]
# 基于词频返回max_vocabulary_size个常用词
count.extend(collections.Counter(text_words).most_common(max_vocabulary_size - 1))

# %% [markdown]
# 默认已经是排序好了的

# %%
count[0:10]
# Out:
# [('UNK', -1),
#  (b'the', 1061396),
#  (b'of', 593677),
#  (b'and', 416629),
#  (b'one', 411764),
#  (b'in', 372201),
#  (b'a', 325873),
#  (b'to', 316376),
#  (b'zero', 264975),
#  (b'nine', 250430)]

# %% [markdown]
# 别忘了，咱们还设置了min_occurrence参数，需要判断每一个词是否满足给定条件

# %%
# 剔除掉出现次数少于'min_occurrence'的词
for i in range(len(count) - 1, -1, -1):# 从start到end每次step多少
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:
        # 判断时，从小到大排序的，所以跳出时候剩下的都是满足条件的
        break

# %% [markdown]
# ### 词-ID映射

# %%
# 计算语料库大小
vocabulary_size = len(count)
# 每个词都分配一个ID
word2id = dict()
for i, (word, _)in enumerate(count):
    word2id[word] = i

# %%
word2id
# Out:
# {'UNK': 0,
#  b'the': 1,
#  b'of': 2,
#  b'and': 3,
#  b'one': 4,
#  b'in': 5,
#  b'a': 6,
#  b'to': 7,
#  b'zero': 8,
#  b'nine': 9,
#  b'two': 10,
#  b'is': 11,
#  b'as': 12,
#  b'eight': 13,
#  b'for': 14,
#  b's': 15,
#  b'five': 16,
#  b'three': 17,
#  b'was': 18,
#  b'by': 19,
#  b'that': 20,
#  b'four': 21,
#  b'six': 22,
#  b'seven': 23,
#  b'with': 24,
#  b'on': 25,
#  b'are': 26,
#  b'it': 27,
#  b'from': 28,
#  b'or': 29,
#  b'his': 30,
#  b'an': 31,
#  b'be': 32,
#  b'this': 33,
#  b'which': 34,
#  b'at': 35,
#  b'he': 36,
#  b'also': 37,
#  b'not': 38,
#  b'have': 39,
#  b'were': 40,
#  b'has': 41,
#  b'but': 42,
#  b'other': 43,
#  b'their': 44,
#  b'its': 45,
#  b'first': 46,
#  b'they': 47,
#  b'some': 48,
#  b'had': 49,
#  b'all': 50,
#  b'more': 51,
#  b'most': 52,
#  b'can': 53,
#  b'been': 54,
#  b'such': 55,
#  b'many': 56,
#  b'who': 57,
#  b'new': 58,
#  b'used': 59,
#  b'there': 60,
#  b'after': 61,
#  b'when': 62,
#  b'into': 63,
#  b'american': 64,
#  b'time': 65,
#  b'these': 66,
#  b'only': 67,
#  b'see': 68,
#  b'may': 69,
#  b'than': 70,
#  b'world': 71,
#  b'i': 72,
#  b'b': 73,
#  b'would': 74,
#  b'd': 75,
#  b'no': 76,
#  b'however': 77,
#  b'between': 78,
#  b'about': 79,
#  b'over': 80,
#  b'years': 81,
#  b'states': 82,
#  b'people': 83,
#  b'war': 84,
#  b'during': 85,
#  b'united': 86,
#  b'known': 87,
#  b'if': 88,
#  b'called': 89,
#  b'use': 90,
#  b'th': 91,
#  b'system': 92,
#  b'often': 93,
#  b'state': 94,
#  b'so': 95,
#  b'history': 96,
#  b'will': 97,
#  b'up': 98,
#  b'while': 99,
#  b'where': 100,
#  b'city': 101,
#  b'being': 102,
#  b'english': 103,
#  b'then': 104,
#  b'any': 105,
#  b'both': 106,
#  b'under': 107,
#  b'out': 108,
#  b'made': 109,
#  b'well': 110,
#  b'her': 111,
#  b'e': 112,
#  b'number': 113,
#  b'government': 114,
#  b'them': 115,
#  b'm': 116,
#  b'later': 117,
#  b'since': 118,
#  b'him': 119,
#  b'part': 120,
#  b'name': 121,
#  b'c': 122,
#  b'century': 123,
#  b'through': 124,
#  b'because': 125,
#  b'x': 126,
#  b'university': 127,
#  b'early': 128,
#  b'life': 129,
#  b'british': 130,
#  b'year': 131,
#  b'like': 132,
#  b'same': 133,
#  b'including': 134,
#  b'became': 135,
#  b'example': 136,
#  b'day': 137,
#  b'each': 138,
#  b'even': 139,
#  b'work': 140,
#  b'language': 141,
#  b'although': 142,
#  b'several': 143,
#  b'form': 144,
#  b'john': 145,
#  b'u': 146,
#  b'national': 147,
#  b'very': 148,
#  b'much': 149,
#  b'g': 150,
#  b'french': 151,
#  b'before': 152,
#  b'general': 153,
#  b'what': 154,
#  b't': 155,
#  b'against': 156,
#  b'n': 157,
#  b'high': 158,
#  b'links': 159,
#  b'could': 160,
#  b'based': 161,
#  b'those': 162,
#  b'now': 163,
#  b'second': 164,
#  b'de': 165,
#  b'music': 166,
#  b'another': 167,
#  b'large': 168,
#  b'she': 169,
#  b'f': 170,
#  b'external': 171,
#  b'german': 172,
#  b'different': 173,
#  b'modern': 174,
#  b'great': 175,
#  b'do': 176,
#  b'common': 177,
#  b'set': 178,
#  b'list': 179,
#  b'south': 180,
#  b'series': 181,
#  b'major': 182,
#  b'game': 183,
#  b'power': 184,
#  b'long': 185,
#  b'country': 186,
#  b'king': 187,
#  b'law': 188,
#  b'group': 189,
#  b'film': 190,
#  b'still': 191,
#  b'until': 192,
#  b'north': 193,
#  b'international': 194,
#  b'term': 195,
#  b'we': 196,
#  b'end': 197,
#  b'book': 198,
#  b'found': 199,
#  b'own': 200,
#  b'political': 201,
#  b'party': 202,
#  b'order': 203,
#  b'usually': 204,
#  b'president': 205,
#  b'church': 206,
#  b'you': 207,
#  b'death': 208,
#  b'theory': 209,
#  b'area': 210,
#  b'around': 211,
#  b'include': 212,
#  b'god': 213,
#  b'ii': 214,
#  b'way': 215,
#  b'did': 216,
#  b'military': 217,
#  b'population': 218,
#  b'using': 219,
#  b'though': 220,
#  b'small': 221,
#  b'following': 222,
#  b'within': 223,
#  b'non': 224,
#  b'human': 225,
#  b'left': 226,
#  b'main': 227,
#  b'among': 228,
#  b'point': 229,
#  b'r': 230,
#  b'due': 231,
#  b'p': 232,
#  b'considered': 233,
#  b'public': 234,
#  b'popular': 235,
#  b'computer': 236,
#  b'west': 237,
#  b'family': 238,
#  b'east': 239,
#  b'information': 240,
#  b'important': 241,
#  b'european': 242,
#  b'man': 243,
#  b'sometimes': 244,
#  b'right': 245,
#  b'old': 246,
#  b'free': 247,
#  b'word': 248,
#  b'without': 249,
#  b'last': 250,
#  b'us': 251,
#  b'members': 252,
#  b'given': 253,
#  b'times': 254,
#  b'roman': 255,
#  b'make': 256,
#  b'h': 257,
#  b'age': 258,
#  b'place': 259,
#  b'l': 260,
#  b'thus': 261,
#  b'science': 262,
#  b'case': 263,
#  b'become': 264,
#  b'systems': 265,
#  b'union': 266,
#  b'born': 267,
#  b'york': 268,
#  b'line': 269,
#  b'countries': 270,
#  b'does': 271,
#  b'isbn': 272,
#  b'st': 273,
#  b'control': 274,
#  b'various': 275,
#  b'others': 276,
#  b'house': 277,
#  b'article': 278,
#  b'island': 279,
#  b'should': 280,
#  b'led': 281,
#  b'back': 282,
#  b'period': 283,
#  b'player': 284,
#  b'europe': 285,
#  b'languages': 286,
#  b'central': 287,
#  b'water': 288,
#  b'few': 289,
#  b'western': 290,
#  b'home': 291,
#  b'began': 292,
#  b'generally': 293,
#  b'less': 294,
#  b'k': 295,
#  b'similar': 296,
#  b'written': 297,
#  b'original': 298,
#  b'best': 299,
#  b'must': 300,
#  b'according': 301,
#  b'school': 302,
#  b'france': 303,
#  b'air': 304,
#  b'single': 305,
#  b'force': 306,
#  b'v': 307,
#  b'land': 308,
#  b'groups': 309,
#  b'down': 310,
#  b'how': 311,
#  b'works': 312,
#  b'development': 313,
#  b'official': 314,
#  b'support': 315,
#  b'england': 316,
#  b'j': 317,
#  b'rather': 318,
#  b'data': 319,
#  b'space': 320,
#  b'greek': 321,
#  b'km': 322,
#  b'named': 323,
#  b'germany': 324,
#  b'just': 325,
#  b'games': 326,
#  b'said': 327,
#  b'version': 328,
#  b'late': 329,
#  b'earth': 330,
#  b'company': 331,
#  b'every': 332,
#  b'economic': 333,
#  b'short': 334,
#  b'published': 335,
#  b'black': 336,
#  b'army': 337,
#  b'off': 338,
#  b'london': 339,
#  b'million': 340,
#  b'body': 341,
#  b'field': 342,
#  b'christian': 343,
#  b'either': 344,
#  b'social': 345,
#  b'empire': 346,
#  b'o': 347,
#  b'developed': 348,
#  b'standard': 349,
#  b'court': 350,
#  b'service': 351,
#  b'kingdom': 352,
#  b'along': 353,
#  b'college': 354,
#  b'republic': 355,
#  b'sea': 356,
#  b'america': 357,
#  b'today': 358,
#  b'result': 359,
#  b'held': 360,
#  b'team': 361,
#  b'light': 362,
#  b'means': 363,
#  b'never': 364,
#  b'especially': 365,
#  b'third': 366,
#  b'further': 367,
#  b'character': 368,
#  b'forces': 369,
#  b'take': 370,
#  b'men': 371,
#  b'society': 372,
#  b'show': 373,
#  b'open': 374,
#  b'possible': 375,
#  b'fact': 376,
#  b'battle': 377,
#  b'took': 378,
#  b'former': 379,
#  b'books': 380,
#  b'soviet': 381,
#  b'river': 382,
#  b'children': 383,
#  b'having': 384,
#  b'good': 385,
#  b'local': 386,
#  b'current': 387,
#  b'son': 388,
#  b'process': 389,
#  b'natural': 390,
#  b'present': 391,
#  b'himself': 392,
#  b'islands': 393,
#  b'total': 394,
#  b'near': 395,
#  b'white': 396,
#  b'days': 397,
#  b'person': 398,
#  b'itself': 399,
#  b'seen': 400,
#  b'culture': 401,
#  b'little': 402,
#  b'above': 403,
#  b'software': 404,
#  b'largest': 405,
#  b'words': 406,
#  b'upon': 407,
#  b'level': 408,
#  b'father': 409,
#  b'created': 410,
#  b'side': 411,
#  b'red': 412,
#  b'references': 413,
#  b'press': 414,
#  b'full': 415,
#  b'region': 416,
#  b'almost': 417,
#  b'image': 418,
#  b'al': 419,
#  b'famous': 420,
#  b'play': 421,
#  b'came': 422,
#  b'role': 423,
#  b'once': 424,
#  b'certain': 425,
#  b'league': 426,
#  b'jewish': 427,
#  b'james': 428,
#  b'january': 429,
#  b'site': 430,
#  b'again': 431,
#  b'numbers': 432,
#  b'art': 433,
#  b'member': 434,
#  b'areas': 435,
#  b'movement': 436,
#  b'religious': 437,
#  b'type': 438,
#  b'march': 439,
#  b'community': 440,
#  b'story': 441,
#  b'played': 442,
#  b'production': 443,
#  b'released': 444,
#  b'center': 445,
#  b'rights': 446,
#  b'real': 447,
#  b'related': 448,
#  b'foreign': 449,
#  b'low': 450,
#  b'ancient': 451,
#  b'terms': 452,
#  b'view': 453,
#  b'source': 454,
#  b'act': 455,
#  b'minister': 456,
#  b'change': 457,
#  b'energy': 458,
#  b'produced': 459,
#  b'research': 460,
#  b'actor': 461,
#  b'making': 462,
#  b'civil': 463,
#  b'december': 464,
#  b'women': 465,
#  b'special': 466,
#  b'style': 467,
#  b'william': 468,
#  b'design': 469,
#  b'japanese': 470,
#  b'available': 471,
#  b'chinese': 472,
#  b'forms': 473,
#  b'canada': 474,
#  b'northern': 475,
#  b'died': 476,
#  b'class': 477,
#  b'living': 478,
#  b'next': 479,
#  b'particular': 480,
#  b'program': 481,
#  b'council': 482,
#  b'television': 483,
#  b'head': 484,
#  b'david': 485,
#  b'china': 486,
#  b'middle': 487,
#  b'established': 488,
#  b'hand': 489,
#  b'bc': 490,
#  b'far': 491,
#  b'july': 492,
#  b'function': 493,
#  b'position': 494,
#  b'y': 495,
#  b'built': 496,
#  b'george': 497,
#  b'band': 498,
#  b'together': 499,
#  b'w': 500,
#  b'latin': 501,
#  b'thought': 502,
#  b'eastern': 503,
#  b'charles': 504,
#  b'parts': 505,
#  b'instead': 506,
#  b'study': 507,
#  b'might': 508,
#  b'india': 509,
#  b'code': 510,
#  b'included': 511,
#  b'meaning': 512,
#  b'trade': 513,
#  b'per': 514,
#  b'june': 515,
#  b'least': 516,
#  b'half': 517,
#  b'model': 518,
#  b'economy': 519,
#  b'prime': 520,
#  b'traditional': 521,
#  b'always': 522,
#  b'capital': 523,
#  b'range': 524,
#  b'november': 525,
#  b'emperor': 526,
#  b'young': 527,
#  b'anti': 528,
#  b'final': 529,
#  b'text': 530,
#  b'players': 531,
#  b'uk': 532,
#  b'april': 533,
#  b'run': 534,
#  b'september': 535,
#  b'addition': 536,
#  b'radio': 537,
#  b'live': 538,
#  b'august': 539,
#  b'taken': 540,
#  b'note': 541,
#  b'italian': 542,
#  b'lost': 543,
#  b'nature': 544,
#  b'project': 545,
#  b'technology': 546,
#  b'spanish': 547,
#  b'october': 548,
#  b'recent': 549,
#  b'rate': 550,
#  b'won': 551,
#  b'true': 552,
#  b'value': 553,
#  b'uses': 554,
#  b'russian': 555,
#  b'est': 556,
#  b'wrote': 557,
#  b'effect': 558,
#  b'album': 559,
#  b'southern': 560,
#  b'africa': 561,
#  b'whose': 562,
#  b'top': 563,
#  b'historical': 564,
#  b'australia': 565,
#  b'catholic': 566,
#  b'particularly': 567,
#  b'self': 568,
#  b'structure': 569,
#  b'record': 570,
#  b'evidence': 571,
#  b'rule': 572,
#  b'themselves': 573,
#  b'influence': 574,
#  b'cases': 575,
#  b'subject': 576,
#  b'referred': 577,
#  b'continued': 578,
#  b'nations': 579,
#  b'below': 580,
#  b'rock': 581,
#  b'japan': 582,
#  b'com': 583,
#  b'song': 584,
#  b'throughout': 585,
#  b'names': 586,
#  b'female': 587,
#  b'title': 588,
#  b'therefore': 589,
#  b'our': 590,
#  b'office': 591,
#  b'star': 592,
#  b'paul': 593,
#  b'too': 594,
#  b'cities': 595,
#  b'february': 596,
#  b'independent': 597,
#  b'author': 598,
#  b'problem': 599,
#  b'species': 600,
#  b'education': 601,
#  b'done': 602,
#  b'philosophy': 603,
#  b'come': 604,
#  b'higher': 605,
#  b'originally': 606,
#  b'market': 607,
#  b'town': 608,
#  b'my': 609,
#  b'season': 610,
#  b'love': 611,
#  b'strong': 612,
#  b'israel': 613,
#  b'irish': 614,
#  b'writer': 615,
#  b'films': 616,
#  b'elements': 617,
#  b'robert': 618,
#  b'whether': 619,
#  b'despite': 620,
#  b'eventually': 621,
#  b'here': 622,
#  b'football': 623,
#  b'action': 624,
#  b'internet': 625,
#  b'individual': 626,
#  b'sound': 627,
#  b'network': 628,
#  b'described': 629,
#  b'practice': 630,
#  b'characters': 631,
#  b're': 632,
#  b'royal': 633,
#  b'la': 634,
#  b'events': 635,
#  b'formed': 636,
#  b'commonly': 637,
#  b'base': 638,
#  b'received': 639,
#  b'african': 640,
#  b'problems': 641,
#  b'food': 642,
#  b'jews': 643,
#  b'able': 644,
#  b'male': 645,
#  b'typically': 646,
#  b'mass': 647,
#  b'complex': 648,
#  b'lower': 649,
#  b'includes': 650,
#  b'outside': 651,
#  b'legal': 652,
#  b'complete': 653,
#  b'significant': 654,
#  b'parliament': 655,
#  b'actually': 656,
#  b'business': 657,
#  b'fiction': 658,
#  b'physical': 659,
#  b'followed': 660,
#  b'deaths': 661,
#  b'key': 662,
#  b'leader': 663,
#  b'widely': 664,
#  b'page': 665,
#  b'basic': 666,
#  b'types': 667,
#  b'henry': 668,
#  b'elected': 669,
#  b'beginning': 670,
#  b'fire': 671,
#  b'building': 672,
#  b'independence': 673,
#  b'went': 674,
#  b'movie': 675,
#  b'aircraft': 676,
#  b'ever': 677,
#  b'canadian': 678,
#  b'material': 679,
#  b'births': 680,
#  b'video': 681,
#  b'news': 682,
#  b'future': 683,
#  b'scientific': 684,
#  b'simply': 685,
#  b'go': 686,
#  b'defined': 687,
#  b'laws': 688,
#  b'get': 689,
#  b'close': 690,
#  b'industry': 691,
#  b'specific': 692,
#  b'examples': 693,
#  b'believe': 694,
#  b'services': 695,
#  b'idea': 696,
#  b'method': 697,
#  b'introduced': 698,
#  b'points': 699,
#  b'return': 700,
#  b'cause': 701,
#  b'indian': 702,
#  b'britain': 703,
#  b'features': 704,
#  b'majority': 705,
#  b'size': 706,
#  b'post': 707,
#  b'lead': 708,
#  b'organization': 709,
#  b'cannot': 710,
#  b'designed': 711,
#  b'ireland': 712,
#  b'cross': 713,
#  b'classical': 714,
#  b'personal': 715,
#  b'writing': 716,
#  b'concept': 717,
#  b'associated': 718,
#  b'required': 719,
#  b'soon': 720,
#  b'changes': 721,
#  b'california': 722,
#  b'located': 723,
#  b'sense': 724,
#  b'believed': 725,
#  b'away': 726,
#  b'started': 727,
#  b'co': 728,
#  b'religion': 729,
#  b'mother': 730,
#  b'county': 731,
#  b'rules': 732,
#  b'studies': 733,
#  b'yet': 734,
#  b'find': 735,
#  b'knowledge': 736,
#  b'put': 737,
#  b'founded': 738,
#  b'policy': 739,
#  b'currently': 740,
#  b'provide': 741,
#  b'working': 742,
#  b'media': 743,
#  b'election': 744,
#  b'australian': 745,
#  b'me': 746,
#  b'thomas': 747,
#  b'allowed': 748,
#  b'russia': 749,
#  b'earlier': 750,
#  b'greater': 751,
#  b'limited': 752,
#  b'object': 753,
#  b'brought': 754,
#  b'online': 755,
#  b'association': 756,
#  b'lord': 757,
#  b'mostly': 758,
#  b'blue': 759,
#  b'constitution': 760,
#  b'across': 761,
#  b'added': 762,
#  b'interest': 763,
#  b'things': 764,
#  b'relations': 765,
#  b'speed': 766,
#  b'federal': 767,
#  b'singer': 768,
#  b'effects': 769,
#  b'growth': 770,
#  b'sources': 771,
#  b'your': 772,
#  b'remains': 773,
#  b'z': 774,
#  b'probably': 775,
#  b'gave': 776,
#  b'simple': 777,
#  b'attack': 778,
#  b'longer': 779,
#  b'reference': 780,
#  b'saint': 781,
#  b'success': 782,
#  b'killed': 783,
#  b'past': 784,
#  b'career': 785,
#  b'need': 786,
#  b'park': 787,
#  b'definition': 788,
#  b'say': 789,
#  b'etc': 790,
#  b'give': 791,
#  b'peace': 792,
#  b'chief': 793,
#  b'stories': 794,
#  b'security': 795,
#  b'wide': 796,
#  b'ball': 797,
#  b'saw': 798,
#  b'machine': 799,
#  b'better': 800,
#  b'cell': 801,
#  b'leading': 802,
#  b'becomes': 803,
#  b'spain': 804,
#  b'larger': 805,
#  b'products': 806,
#  b'parties': 807,
#  b'night': 808,
#  b'remained': 809,
#  b'prize': 810,
#  b'months': 811,
#  b'website': 812,
#  b'big': 813,
#  b'cultural': 814,
#  b'money': 815,
#  b'help': 816,
#  b'territory': 817,
#  b'private': 818,
#  b'moved': 819,
#  b'letter': 820,
#  b'wife': 821,
#  b'politics': 822,
#  b'lines': 823,
#  b'largely': 824,
#  b'contains': 825,
#  b'companies': 826,
#  b'lake': 827,
#  b'perhaps': 828,
#  b'green': 829,
#  b'already': 830,
#  b'dead': 831,
#  b'iii': 832,
#  b'library': 833,
#  b'separate': 834,
#  b'refer': 835,
#  b'makes': 836,
#  b'appeared': 837,
#  b'dutch': 838,
#  b'holy': 839,
#  b'era': 840,
#  b'novel': 841,
#  b'successful': 842,
#  b'italy': 843,
#  b'letters': 844,
#  b'results': 845,
#  b'matter': 846,
#  b'produce': 847,
#  b'origin': 848,
#  b'claim': 849,
#  b'whole': 850,
#  b'directly': 851,
#  b'attempt': 852,
#  b'actress': 853,
#  b'surface': 854,
#  b'revolution': 855,
#  b'highly': 856,
#  b'caused': 857,
#  b'status': 858,
#  b'musical': 859,
#  b'richard': 860,
#  b'commercial': 861,
#  b'division': 862,
#  b'color': 863,
#  b'health': 864,
#  b'coast': 865,
#  b'release': 866,
#  b'latter': 867,
#  b'authority': 868,
#  b'treaty': 869,
#  b'turn': 870,
#  b'michael': 871,
#  b'nation': 872,
#  b'direct': 873,
#  b'asia': 874,
#  b'edition': 875,
#  b'programming': 876,
#  b'playing': 877,
#  b'date': 878,
#  b'mary': 879,
#  b'native': 880,
#  b'whom': 881,
#  b'married': 882,
#  b'towards': 883,
#  b'issues': 884,
#  b'double': 885,
#  b'primary': 886,
#  b'basis': 887,
#  b'allow': 888,
#  b'enough': 889,
#  b'memory': 890,
#  b'reason': 891,
#  b'web': 892,
#  b'exist': 893,
#  b'provided': 894,
#  b'oil': 895,
#  b'course': 896,
#  b'functions': 897,
#  b'alexander': 898,
#  b'analysis': 899,
#  b'chemical': 900,
#  b'mid': 901,
#  b'replaced': 902,
#  b'queen': 903,
#  b'claims': 904,
#  b'tv': 905,
#  b'sun': 906,
#  b'literature': 907,
#  b'metal': 908,
#  b'amount': 909,
#  b'divided': 910,
#  b'blood': 911,
#  b'likely': 912,
#  b'access': 913,
#  b'average': 914,
#  b'length': 915,
#  b'smaller': 916,
#  b'medical': 917,
#  b'property': 918,
#  b'students': 919,
#  b'degree': 920,
#  b'elections': 921,
#  b'club': 922,
#  b'claimed': 923,
#  b'performance': 924,
#  b'director': 925,
#  b'digital': 926,
#  b'front': 927,
#  b'museum': 928,
#  b'difficult': 929,
#  b'tradition': 930,
#  b'nearly': 931,
#  b'schools': 932,
#  b'washington': 933,
#  b'gas': 934,
#  b'jesus': 935,
#  b'map': 936,
#  b'louis': 937,
#  b'rome': 938,
#  b'unit': 939,
#  b'baseball': 940,
#  b'mind': 941,
#  b'peter': 942,
#  b'mark': 943,
#  b'collection': 944,
#  b'product': 945,
#  b'congress': 946,
#  b'programs': 947,
#  b'changed': 948,
#  b'ideas': 949,
#  b'moon': 950,
#  b'entire': 951,
#  b'user': 952,
#  b'ground': 953,
#  b'records': 954,
#  b'frequently': 955,
#  b'increase': 956,
#  b'highest': 957,
#  b'sent': 958,
#  b'finally': 959,
#  b'board': 960,
#  b'don': 961,
#  b'notable': 962,
#  b'read': 963,
#  b'methods': 964,
#  b'recently': 965,
#  b'bit': 966,
#  b'involved': 967,
#  b'variety': 968,
#  b'call': 969,
#  b'democratic': 970,
#  b'ten': 971,
#  b'served': 972,
#  b'minor': 973,
#  b'hard': 974,
#  b'birth': 975,
#  b'objects': 976,
#  b'nuclear': 977,
#  b'increased': 978,
#  b'section': 979,
#  b'street': 980,
#  b'windows': 981,
#  b'relatively': 982,
#  b'car': 983,
#  b'move': 984,
#  b'create': 985,
#  b'returned': 986,
#  b'bank': 987,
#  b'conditions': 988,
#  b'operation': 989,
#  b'adopted': 990,
#  b'relationship': 991,
#  b'christ': 992,
#  b'hall': 993,
#  b'appear': 994,
#  b'rest': 995,
#  b'child': 996,
#  b'element': 997,
#  b'appears': 998,
#  b'takes': 999,
#  ...}

# %% [markdown]
# ### 所有词转换成ID

# %%
data = list()
unk_count = 0
for word in text_words:
    # 全部转换成id
    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)
count[0] = ('UNK', unk_count)
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", vocabulary_size)
print("Most common words:", count[:10])
# Out:
# Words count: 17005207
# Unique words: 253854
# Vocabulary size: 47135
# Most common words: [('UNK', 444176), (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764), (b'in', 372201), (b'a', 325873), (b'to', 316376), (b'zero', 264975), (b'nine', 250430)]

# %% [markdown]
# ### 构建所需训练数据

# %%
data_index = 0

def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # get window size (words left and right + current one).
    span = 2 * skip_window + 1 #7为窗口，左3右3中间1
    buffer = collections.deque(maxlen=span)#创建一个长度为7的队列
    if data_index + span > len(data):#如果数据被滑完一遍了
        data_index = 0
    buffer.extend(data[data_index:data_index + span])#队列里存的是当前窗口，例如deque([5234, 3081, 12, 6, 195, 2, 3134], maxlen=7)
    data_index += span
    for i in range(batch_size // num_skips):#num_skips表示取多少组不同的词作为输出，此例为2
        context_words = [w for w in range(span) if w != skip_window]#上下文就是[0, 1, 2, 4, 5, 6]
        words_to_use = random.sample(context_words, num_skips)#在上下文里随机选2个候选词
        for j, context_word in enumerate(words_to_use):#遍历每一个候选词，用其当做输出也就是标签
            batch[i * num_skips + j] = buffer[skip_window]#输入都为当前窗口的中间词，即3
            labels[i * num_skips + j, 0] = buffer[context_word]#用当前候选词当做标签
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])#之前已经传入7个词了，窗口要右移了，例如原来为[5234, 3081, 12, 6, 195, 2, 3134]，现在为[3081, 12, 6, 195, 2, 3134, 46]
            data_index += 1

    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
# with tf.device('/cpu:0'):
# with tf.device('/device:GPU:1'):
embedding = tf.Variable(tf.random.normal([vocabulary_size, embedding_size])) #维度：47135, 200
nce_weights = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# %% [markdown]
# ### 通过tf.nn.embedding_lookup函数将索引转换成词向量

# %%
def get_embedding(x):
#     with tf.device('/cpu:0'):
#     with tf.device('/device:GPU:1'):
        x_embed = tf.nn.embedding_lookup(embedding, x)
        return x_embed

# %% [markdown]
# ### 损失函数定义
# - 先分别计算出正样本和采样出的负样本对应的output和label
# - 再通过 sigmoid cross entropy来计算output和label的loss

# %%
def nce_loss(x_embed, y):
#     with tf.device('/cpu:0'):
#     with tf.device('/device:GPU:1'):
        y = tf.cast(y, tf.int64)
        loss = tf.reduce_mean(
            tf.nn.nce_loss(weights=nce_weights,
                           biases=nce_biases,
                           labels=y,
                           inputs=x_embed,
                           num_sampled=num_sampled,#采样出多少个负样本
                           num_classes=vocabulary_size))
        return loss

# %% [markdown]
# ### 测试观察模块

# %%
# Evaluation.
def evaluate(x_embed):
#     with tf.device('/cpu:0'):
#     with tf.device('/device:GPU:1'):
        # Compute the cosine similarity between input data embedding and every embedding vectors
        x_embed = tf.cast(x_embed, tf.float32)
        x_embed_norm = x_embed / tf.sqrt(tf.reduce_sum(tf.square(x_embed)))#归一化
        embedding_norm = embedding / tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True), tf.float32)#全部向量的
        cosine_sim_op = tf.matmul(x_embed_norm, embedding_norm, transpose_b=True)#计算余弦相似度
        return cosine_sim_op

# SGD
optimizer = tf.optimizers.SGD(learning_rate)

# %%
# 迭代优化
def run_optimization(x, y):
#     with tf.device('/cpu:0'):
#     with tf.device('/device:GPU:1'):
        with tf.GradientTape() as g:
            emb = get_embedding(x)
            loss = nce_loss(emb, y)

        # 计算梯度
        gradients = g.gradient(loss, [embedding, nce_weights, nce_biases])

        # 更新
        optimizer.apply_gradients(zip(gradients, [embedding, nce_weights, nce_biases]))

# %%
# 待测试的几个词
x_test = np.array([word2id[w.encode('utf-8')] for w in eval_words])

# 训练
for step in range(1, num_steps + 1):
    batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
    run_optimization(batch_x, batch_y)
    
    if step % display_step == 0 or step == 1:
        loss = nce_loss(get_embedding(batch_x), batch_y)
        print("step: %i, loss: %f" % (step, loss))
        
    # Evaluation.
    if step % eval_step == 0 or step == 1:
        print("Evaluation...")
        sim = evaluate(get_embedding(x_test)).numpy()
        for i in range(len(eval_words)):
            top_k = 8  # 返回前8个最相似的
            nearest = (-sim[i, :]).argsort()[1:top_k + 1]
            log_str = '"%s" nearest neighbors:' % eval_words[i]
            for k in range(top_k):
                log_str = '%s %s,' % (log_str, id2word[nearest[k]])
            print(log_str)
# Out:
# step: 1, loss: 534.524780
# Evaluation...
# "nine" nearest neighbors: b'confine', b'sanger', b'nanna', b'genteel', b'bathroom', b'assaulting', b'antiquark', b'bundled',
# "of" nearest neighbors: b'wharton', b'puccini', b'carbines', b'masorti', b'dk', b'hound', b'poz', b'discover',
# "going" nearest neighbors: b'smit', b'gcl', b'semitism', b'mortgage', b'hypertext', b'legitimized', b'sint', b'kemp',
# "hardware" nearest neighbors: b'come', b'rice', b'syringe', b'saipan', b'complicates', b'retrieval', b'annotated', b'please',
# "american" nearest neighbors: b'aelius', b'weinstein', b'regionally', b'disrespectful', b'personae', b'crisis', b'voluntarily', b'mesopotamian',
# "britain" nearest neighbors: b'sqrt', b'zeppo', b'libyans', b'antidote', b'club', b'tiger', b'rterbuch', b'azrael',
# step: 10000, loss: 126.103729
# step: 20000, loss: 69.908478
# step: 30000, loss: 45.935303
# step: 40000, loss: 19.961370
# step: 50000, loss: 44.816113
# step: 60000, loss: 49.189308
# step: 70000, loss: 15.190489
# step: 80000, loss: 28.343447
# step: 90000, loss: 52.438534
# step: 100000, loss: 38.231438
# step: 110000, loss: 29.194086
# step: 120000, loss: 14.317377
# step: 130000, loss: 29.926218
# step: 140000, loss: 35.140812
# step: 150000, loss: 10.208322
# step: 160000, loss: 26.255972
# step: 170000, loss: 12.588637
# step: 180000, loss: 19.421913
# step: 190000, loss: 10.259373
# step: 200000, loss: 15.642268
# Evaluation...
# "nine" nearest neighbors: b'seven', b'eight', b'four', b'five', b'three', b'six', b'two', b'one',
# "of" nearest neighbors: b'the', b'and', b'first', b'a', b'for', b'was', b'in', b'is',
# "going" nearest neighbors: b's', b'in', b'from', b'a', b'was', b'his', b'right', UNK,
# "hardware" nearest neighbors: b'come', b'event', b'recorded', b'place', b'ft', b'quantum', b'concept', b'context',
# "american" nearest neighbors: UNK, b'and', b'about', b'when', b'in', b'after', b's', b'from',
# "britain" nearest neighbors: b'his', b'like', b'if', b's', b'who', b'most', b'people', b'where',
# step: 210000, loss: 15.108610
# step: 220000, loss: 15.534017
# step: 230000, loss: 14.625582
# step: 240000, loss: 7.132862
# step: 250000, loss: 8.832026
# step: 260000, loss: 13.287501
# step: 270000, loss: 9.331589
# step: 280000, loss: 7.462160
# step: 290000, loss: 9.013559
# step: 300000, loss: 11.012263
# step: 310000, loss: 16.373728
# step: 320000, loss: 11.463525
# step: 330000, loss: 8.926619
# step: 340000, loss: 12.294724
# step: 350000, loss: 14.888187
# step: 360000, loss: 8.617085
# step: 370000, loss: 8.109228
# step: 380000, loss: 7.710183
# step: 390000, loss: 8.019155
# step: 400000, loss: 9.795823
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'one', b'three', b'two',
# "of" nearest neighbors: b'a', b'the', b'and', b'for', b'its', b'which', b'in', b'or',
# "going" nearest neighbors: b'right', b'of', b'by', b'life', b'john', b'he', b'up', b'her',
# "hardware" nearest neighbors: b'law', b'known', b'such', b'used', b'well', b'called', b'name', b'use',
# "american" nearest neighbors: b's', b'in', UNK, b'and', b'british', b'english', b'including', b'when',
# "britain" nearest neighbors: b'major', b'his', b'where', b'life', b'national', b'people', b'see', b'during',
# step: 410000, loss: 6.733793
# step: 420000, loss: 13.548132
# step: 430000, loss: 12.659308
# step: 440000, loss: 8.065626
# step: 450000, loss: 5.856223
# step: 460000, loss: 11.583954
# step: 470000, loss: 6.501516
# step: 480000, loss: 16.638538
# step: 490000, loss: 6.086221
# step: 500000, loss: 11.213154
# step: 510000, loss: 11.177975
# step: 520000, loss: 8.080305
# step: 530000, loss: 7.577922
# step: 540000, loss: 7.208690
# step: 550000, loss: 10.778997
# step: 560000, loss: 7.777089
# step: 570000, loss: 6.327035
# step: 580000, loss: 6.848868
# step: 590000, loss: 6.396438
# step: 600000, loss: 6.217451
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'one', b'four', b'five', b'three', b'two',
# "of" nearest neighbors: b'and', b'the', b'in', b'for', b'by', b'including', b'while', b'an',
# "going" nearest neighbors: b'right', b'left', b'from', b'great', b'on', b'where', b'major', b'people',
# "hardware" nearest neighbors: b'this', b'place', b'based', b'power', b'had', b'using', b'for', b'called',
# "american" nearest neighbors: b'english', b'german', b'french', b'film', b's', b'from', b'and', b'in',
# "britain" nearest neighbors: b'where', b'people', b'film', b'first', b'his', b'national', b'second', b'on',
# step: 610000, loss: 3.562418
# step: 620000, loss: 6.258121
# step: 630000, loss: 7.106475
# step: 640000, loss: 9.585881
# step: 650000, loss: 6.601875
# step: 660000, loss: 8.220770
# step: 670000, loss: 5.629663
# step: 680000, loss: 4.772699
# step: 690000, loss: 7.168667
# step: 700000, loss: 7.329035
# step: 710000, loss: 12.840011
# step: 720000, loss: 6.466900
# step: 730000, loss: 6.524770
# step: 740000, loss: 6.698543
# step: 750000, loss: 12.455490
# step: 760000, loss: 7.570901
# step: 770000, loss: 15.077131
# step: 780000, loss: 7.777150
# step: 790000, loss: 8.231457
# step: 800000, loss: 6.115523
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'one', b'five', b'three', b'two',
# "of" nearest neighbors: b'and', b'the', b'a', b'including', b'with', b'for', b'from', b'by',
# "going" nearest neighbors: b'right', b'left', b'she', b'book', b'second', b'people', b'popular', b'her',
# "hardware" nearest neighbors: b'place', b'such', b'based', b'using', b'for', b'word', b'like', b'called',
# "american" nearest neighbors: b'born', b'english', b'french', b'b', b'british', b'd', b'john', b'german',
# "britain" nearest neighbors: b'people', b'island', b'north', b'from', b'south', b'national', b'where', b'country',
# step: 810000, loss: 7.358844
# step: 820000, loss: 6.160007
# step: 830000, loss: 7.707833
# step: 840000, loss: 5.281965
# step: 850000, loss: 7.472687
# step: 860000, loss: 7.022272
# step: 870000, loss: 5.025089
# step: 880000, loss: 7.796624
# step: 890000, loss: 6.748011
# step: 900000, loss: 5.618918
# step: 910000, loss: 7.425099
# step: 920000, loss: 7.316322
# step: 930000, loss: 6.957608
# step: 940000, loss: 6.844067
# step: 950000, loss: 8.049061
# step: 960000, loss: 6.034753
# step: 970000, loss: 7.231713
# step: 980000, loss: 4.763393
# step: 990000, loss: 6.198802
# step: 1000000, loss: 5.635044
# Evaluation...
# "nine" nearest neighbors: b'seven', b'eight', b'six', b'four', b'three', b'five', b'one', b'two',
# "of" nearest neighbors: b'the', b'became', b'first', b'from', b'and', b'including', b'on', b'following',
# "going" nearest neighbors: b'right', b'left', b'he', b'his', b'popular', b'were', b'him', b'second',
# "hardware" nearest neighbors: b'place', b'through', b'using', b'word', b'such', b'power', b'based', b'data',
# "american" nearest neighbors: b'd', b'b', b'born', UNK, b'john', b'french', b'nine', b'english',
# "britain" nearest neighbors: b'of', b'france', b'where', b'people', b'country', b'the', b'and', b'against',
# step: 1010000, loss: 5.643936
# step: 1020000, loss: 5.383983
# step: 1030000, loss: 8.683529
# step: 1040000, loss: 6.146902
# step: 1050000, loss: 7.351119
# step: 1060000, loss: 5.362917
# step: 1070000, loss: 8.013114
# step: 1080000, loss: 6.379573
# step: 1090000, loss: 6.052934
# step: 1100000, loss: 6.147001
# step: 1110000, loss: 6.940376
# step: 1120000, loss: 6.175217
# step: 1130000, loss: 6.170499
# step: 1140000, loss: 5.550366
# step: 1150000, loss: 5.574723
# step: 1160000, loss: 5.679876
# step: 1170000, loss: 8.422812
# step: 1180000, loss: 6.615170
# step: 1190000, loss: 6.587978
# step: 1200000, loss: 7.555182
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'three', b'one', b'two',
# "of" nearest neighbors: b'the', b'and', b'in', b'its', b'following', b'with', b'including', b'became',
# "going" nearest neighbors: b'right', b'popular', b'him', b'place', b'he', b'his', b'left', b'major',
# "hardware" nearest neighbors: b'data', b'based', b'word', b'through', b'using', b'home', b'place', b'developed',
# "american" nearest neighbors: b'born', b'john', b'german', UNK, b'b', b'd', b'french', b's',
# "britain" nearest neighbors: b'france', b'where', b'took', b'europe', b'major', b'country', b'during', b'north',
# step: 1210000, loss: 6.319704
# step: 1220000, loss: 6.753471
# step: 1230000, loss: 6.325021
# step: 1240000, loss: 6.287709
# step: 1250000, loss: 5.782654
# step: 1260000, loss: 6.992192
# step: 1270000, loss: 6.706500
# step: 1280000, loss: 9.317051
# step: 1290000, loss: 5.686193
# step: 1300000, loss: 7.198241
# step: 1310000, loss: 5.680265
# step: 1320000, loss: 6.090122
# step: 1330000, loss: 6.499246
# step: 1340000, loss: 5.889851
# step: 1350000, loss: 6.715440
# step: 1360000, loss: 8.097772
# step: 1370000, loss: 5.451784
# step: 1380000, loss: 5.186894
# step: 1390000, loss: 5.536626
# step: 1400000, loss: 6.191582
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'one', b'three', b'two',
# "of" nearest neighbors: b'the', b'its', b'and', b'within', b'in', b'modern', b'for', b'including',
# "going" nearest neighbors: b'right', b'left', b'himself', b'place', b'written', b'with', b'when', b'popular',
# "hardware" nearest neighbors: b'based', b'data', b'using', b'further', b'its', b'power', b'developed', b'support',
# "american" nearest neighbors: b'french', b'english', b'german', b'film', b'born', b'british', b'david', b's',
# "britain" nearest neighbors: b'france', b'england', b'first', b'took', b'where', b'europe', b'country', b'british',
# step: 1410000, loss: 6.801477
# step: 1420000, loss: 4.385204
# step: 1430000, loss: 5.254623
# step: 1440000, loss: 6.336686
# step: 1450000, loss: 5.296283
# step: 1460000, loss: 6.199055
# step: 1470000, loss: 6.796807
# step: 1480000, loss: 5.957504
# step: 1490000, loss: 5.088996
# step: 1500000, loss: 4.997263
# step: 1510000, loss: 6.581426
# step: 1520000, loss: 6.019262
# step: 1530000, loss: 5.614148
# step: 1540000, loss: 6.960484
# step: 1550000, loss: 6.691484
# step: 1570000, loss: 5.999516
# step: 1580000, loss: 4.706437
# step: 1590000, loss: 8.070863
# step: 1600000, loss: 6.503515
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'five', b'four', b'three', b'one', b'two',
# "of" nearest neighbors: b'and', b'including', b'the', b'in', b'through', b'especially', b'from', b'with',
# "going" nearest neighbors: b'right', b'left', b'women', b'written', b'where', b'himself', b'up', b'she',
# "hardware" nearest neighbors: b'based', b'using', b'for', b'data', b'making', b'further', b'high', b'word',
# "american" nearest neighbors: b'born', b'british', b'english', b'french', b'john', b'german', b'b', b'd',
# "britain" nearest neighbors: b'france', b'england', b'people', b'europe', b'north', b'country', b'germany', b'in',
# step: 1610000, loss: 6.205321
# step: 1620000, loss: 5.215947
# step: 1630000, loss: 6.049130
# step: 1640000, loss: 5.512667
# step: 1650000, loss: 6.784510
# step: 1660000, loss: 7.041166
# step: 1670000, loss: 4.829408
# step: 1680000, loss: 4.943130
# step: 1690000, loss: 5.362206
# step: 1700000, loss: 6.597115
# step: 1710000, loss: 5.547566
# step: 1720000, loss: 5.951273
# step: 1730000, loss: 5.276620
# step: 1740000, loss: 5.646330
# step: 1750000, loss: 5.682356
# step: 1760000, loss: 11.337085
# step: 1770000, loss: 5.116474
# step: 1780000, loss: 4.912625
# step: 1790000, loss: 4.806989
# step: 1800000, loss: 7.104687
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'three', b'five', b'two', b'one',
# "of" nearest neighbors: b'the', b'including', b'became', b'from', b'first', b'following', b'and', b'in',
# "going" nearest neighbors: b'left', b'his', b'right', b'where', b'he', b'women', b'up', b'place',
# "hardware" nearest neighbors: b'data', b'its', b'services', b'for', b'based', b'using', b'system', b'through',
# "american" nearest neighbors: b'd', b'b', b'born', UNK, b'actor', b'english', b'william', b'nine',
# "britain" nearest neighbors: b'france', b'england', b'europe', b'of', b'following', b'great', b'country', b'against',
# step: 1810000, loss: 5.737472
# step: 1820000, loss: 5.354705
# step: 1830000, loss: 6.695004
# step: 1840000, loss: 5.344868
# step: 1850000, loss: 5.483689
# step: 1860000, loss: 6.217763
# step: 1890000, loss: 5.604012
# step: 1900000, loss: 5.171498
# step: 1910000, loss: 5.776856
# step: 1920000, loss: 4.998712
# step: 1930000, loss: 7.102237
# step: 1940000, loss: 5.514099
# step: 1950000, loss: 5.292378
# step: 1960000, loss: 6.385384
# step: 1970000, loss: 5.224916
# step: 1980000, loss: 5.955207
# step: 1990000, loss: 7.046124
# step: 2000000, loss: 6.128747
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'three', b'one', b'two',
# "of" nearest neighbors: b'and', b'including', b'the', b'with', b'in', b'its', b'following', b'especially',
# "going" nearest neighbors: b'right', b'him', b'women', b'he', b'upon', b'with', b'up', b'place',
# "hardware" nearest neighbors: b'data', b'computer', b'based', b'services', b'using', b'action', b'source', b'developed',
# "american" nearest neighbors: b'born', b'actor', b'd', b'german', b'john', b'david', b'william', b'b',
# "britain" nearest neighbors: b'france', b'england', b'europe', b'following', b'germany', b'people', b'great', b'against',
# step: 2010000, loss: 5.632601
# step: 2020000, loss: 5.849408
# step: 2030000, loss: 5.501714
# step: 2040000, loss: 6.399728
# step: 2050000, loss: 4.901619
# step: 2060000, loss: 4.625626
# step: 2070000, loss: 5.184709
# step: 2080000, loss: 4.537990
# step: 2090000, loss: 4.697159
# step: 2100000, loss: 5.505757
# step: 2110000, loss: 5.891495
# step: 2120000, loss: 6.631836
# step: 2130000, loss: 5.512220
# step: 2140000, loss: 7.066647
# step: 2150000, loss: 5.809556
# step: 2160000, loss: 5.125917
# step: 2170000, loss: 5.563065
# step: 2180000, loss: 5.751313
# step: 2190000, loss: 5.416104
# step: 2200000, loss: 7.819777
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'one', b'five', b'three', b'two',
# "of" nearest neighbors: b'the', b'and', b'including', b'in', b'with', b'from', b'its', b'for',
# "going" nearest neighbors: b'right', b'when', b'him', b'upon', b'just', b'only', b'women', b'ever',
# "hardware" nearest neighbors: b'based', b'computer', b'services', b'data', b'using', b'for', b'source', b'information',
# "american" nearest neighbors: b'english', b'german', b'french', b'british', b'born', b'film', b'author', b'david',
# "britain" nearest neighbors: b'france', b'england', b'europe', b'germany', b'took', b'against', b'country', b'throughout',
# step: 2210000, loss: 4.440763
# step: 2220000, loss: 7.260960
# step: 2230000, loss: 5.368492
# step: 2240000, loss: 7.690886
# step: 2250000, loss: 5.403264
# step: 2260000, loss: 4.938537
# step: 2270000, loss: 8.980488
# step: 2280000, loss: 5.658623
# step: 2290000, loss: 5.861526
# step: 2300000, loss: 5.753673
# step: 2310000, loss: 5.918381
# step: 2320000, loss: 5.225877
# step: 2330000, loss: 6.531522
# step: 2340000, loss: 5.374049
# step: 2350000, loss: 5.983833
# step: 2360000, loss: 5.729882
# step: 2370000, loss: 6.405802
# step: 2380000, loss: 6.644079
# step: 2390000, loss: 5.898539
# step: 2400000, loss: 6.848514
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'three', b'one', b'two',
# "of" nearest neighbors: b'and', b'including', b'in', b'the', b'with', b'especially', b'from', b'original',
# "going" nearest neighbors: b'up', b'right', b'where', b'ever', b'upon', b'women', b'he', b'him',
# "hardware" nearest neighbors: b'based', b'computer', b'data', b'services', b'using', b'information', b'higher', b'system',
# "american" nearest neighbors: b'author', b'actor', b'born', b'english', b'writer', b'd', b'french', b'british',
# "britain" nearest neighbors: b'france', b'england', b'germany', b'europe', b'against', b'country', b'following', b'took',
# step: 2410000, loss: 5.220605
# step: 2420000, loss: 5.339690
# step: 2430000, loss: 4.887603
# step: 2440000, loss: 5.041276
# step: 2450000, loss: 5.124005
# step: 2460000, loss: 5.283481
# step: 2470000, loss: 6.287475
# step: 2480000, loss: 5.782519
# step: 2490000, loss: 5.047735
# step: 2500000, loss: 5.911649
# step: 2510000, loss: 5.227835
# step: 2520000, loss: 5.326851
# step: 2530000, loss: 6.916089
# step: 2540000, loss: 5.035775
# step: 2550000, loss: 5.208927
# step: 2560000, loss: 5.133836
# step: 2570000, loss: 6.431746
# step: 2580000, loss: 5.678991
# step: 2590000, loss: 6.258055
# step: 2600000, loss: 5.189840
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'three', b'two', b'one',
# "of" nearest neighbors: b'the', b'and', b'from', b'became', b'including', b'following', b'for', b'first',
# "going" nearest neighbors: b'right', b'up', b'to', b'place', b'ever', b'once', b'where', b'a',
# "hardware" nearest neighbors: b'data', b'computer', b'using', b'based', b'services', b'system', b'free', b'source',
# "american" nearest neighbors: b'actor', b'b', b'd', b'born', b'author', b'writer', b'singer', b'english',
# "britain" nearest neighbors: b'france', b'england', b'germany', b'against', b'europe', b'became', b'india', b'country',
# step: 2610000, loss: 8.054343
# step: 2620000, loss: 6.118631
# step: 2630000, loss: 5.809227
# step: 2640000, loss: 5.257919
# step: 2650000, loss: 5.221446
# step: 2660000, loss: 6.783541
# step: 2670000, loss: 6.184320
# step: 2680000, loss: 6.185931
# step: 2690000, loss: 5.951024
# step: 2700000, loss: 6.090920
# step: 2710000, loss: 6.096722
# step: 2720000, loss: 5.499233
# step: 2730000, loss: 5.726543
# step: 2740000, loss: 6.034567
# step: 2750000, loss: 4.693501
# step: 2760000, loss: 5.636025
# step: 2770000, loss: 5.618172
# step: 2780000, loss: 6.564797
# step: 2790000, loss: 4.713462
# step: 2800000, loss: 5.471107
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'five', b'four', b'three', b'one', b'two',
# "of" nearest neighbors: b'the', b'in', b'and', b'including', b'from', b'following', b'includes', b'on',
# "going" nearest neighbors: b'right', b'place', b'ever', b'once', b'women', b'up', b'with', b'where',
# "hardware" nearest neighbors: b'computer', b'data', b'using', b'information', b'source', b'services', b'system', b'making',
# "american" nearest neighbors: b'actor', b'born', b'singer', b'writer', b'author', b'canadian', b'd', b'john',
# "britain" nearest neighbors: b'france', b'england', b'germany', b'great', b'israel', b'against', b'established', b'europe',
# step: 2810000, loss: 5.589287
# step: 2820000, loss: 6.847963
# step: 2830000, loss: 7.279382
# step: 2840000, loss: 7.494891
# step: 2850000, loss: 5.742790
# step: 2860000, loss: 5.206226
# step: 2870000, loss: 6.194009
# step: 2880000, loss: 5.528221
# step: 2890000, loss: 6.112661
# step: 2900000, loss: 5.364439
# step: 2910000, loss: 5.416513
# step: 2920000, loss: 5.867843
# step: 2930000, loss: 4.846860
# step: 2940000, loss: 6.935321
# step: 2950000, loss: 4.650046
# step: 2960000, loss: 6.521443
# step: 2970000, loss: 5.735433
# step: 2980000, loss: 6.386697
# step: 2990000, loss: 5.394360
# step: 3000000, loss: 6.057268
# Evaluation...
# "nine" nearest neighbors: b'eight', b'seven', b'six', b'four', b'five', b'one', b'three', b'two',
# "of" nearest neighbors: b'the', b'and', b'in', b'includes', b'with', b'include', b'including', b'its',
# "going" nearest neighbors: b'right', b'only', b'to', b'ever', b'once', b'him', b'where', b'when',
# "hardware" nearest neighbors: b'computer', b'data', b'using', b'system', b'based', b'making', b'source', b'digital',
# "american" nearest neighbors: b'canadian', b'english', b'irish', b'french', b'author', b'german', b'british', b'australian',
# "britain" nearest neighbors: b'france', b'england', b'germany', b'israel', b'great', b'throughout', b'former', b'europe',
