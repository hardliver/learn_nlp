# %% [markdown]
# ### 文本分类任务实战
#
# - 数据集构建：影评数据集进行情感分析（分类任务）
# - 词向量模型：加载训练好的词向量或者自己训练都可以
# - 序列网络模型：训练RNN模型进行识别

# %% [markdown]
# ![title](./img/SentimentAnalysis2.png)

# %% [markdown]
# ### RNN模型所需数据解读：
#
# ![title](./img/1.png)

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
import numpy as np
import pprint
import logging
import time
from collections import Counter
from pathlib import Path
from tqdm import tqdm

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# 加载影评数据集，可以手动下载放到对应位置

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data()

# %%
x_train.shape
# Out:
# (25000,)

# %% [markdown]
# 读进来的数据是已经转换成ID映射的，一般的数据读进来都是词语，都需要手动转换成ID映射的

# %%
print(x_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %% [markdown]
# 词和ID的映射表，空出来3个的目的是加上特殊字符

# %%
_word2idx = tf.keras.datasets.imdb.get_word_index()
word2idx = {w: i+3 for w, i in _word2idx.items()}
word2idx['<pad>'] = 0
word2idx['<start>'] = 1
word2idx['<unk>'] = 2
idx2word = {i: w for w, i in word2idx.items()}

# %% [markdown]
# 按文本长度大小进行排序

# %%
def sort_by_len(x, y):
    x, y = np.asarray(x), np.asarray(y)
    idx = sorted(range(len(x)), key=lambda i: len(x[i]))
    return x[idx], y[idx]

# %% [markdown]
# 将中间结果保存到本地，万一程序崩了还得重玩，保存的是文本数据，不是ID

# %%
x_train, y_train = sort_by_len(x_train, y_train)
x_test, y_test = sort_by_len(x_test, y_test)

def write_file(f_path, xs, ys):
    with open(f_path, 'w',encoding='utf-8') as f:
        for x, y in zip(xs, ys):
            f.write(str(y)+'\t'+' '.join([idx2word[i] for i in x][1:])+'\n')

write_file('./data/train.txt', x_train, y_train)
write_file('./data/test.txt', x_test, y_test)

# %% [markdown]
# ### 构建语料表，基于词频来进行统计

# %%
counter = Counter()
with open('./data/train.txt',encoding='utf-8') as f:
    for line in f:
        line = line.rstrip()
        label, words = line.split('\t')
        words = words.split(' ')
        counter.update(words)

words = ['<pad>'] + [w for w, freq in counter.most_common() if freq >= 10]
print('Vocab Size:', len(words))

Path('./vocab').mkdir(exist_ok=True)

with open('./vocab/word.txt', 'w',encoding='utf-8') as f:
    for w in words:
        f.write(w+'\n')
# Out:
# Vocab Size: 20598

# %% [markdown]
# 得到新的word2id映射表

# %%
word2idx = {}
with open('./vocab/word.txt',encoding='utf-8') as f:
    for i, line in enumerate(f):
        line = line.rstrip()
        word2idx[line] = i

# %% [markdown]
# ### embedding层
# - 可以基于网络来训练，也可以直接加载别人训练好的，一般都是加载预训练模型
# - 这里有一些常用的：https://nlp.stanford.edu/projects/glove/

# %% [markdown]
# ![title](./img/SentimentAnalysis3.png)

# %%
#做了一个大表，里面有20598个不同的词，【20599*50】
embedding = np.zeros((len(word2idx)+1, 50)) # + 1 表示如果不在语料表中，就都是unknow

with open('./data/glove.6B.50d.txt',encoding='utf-8') as f: #下载好的
    count = 0
    for i, line in enumerate(f):
        if i % 100000 == 0:
            print('- At line {}'.format(i)) #打印处理了多少数据
        line = line.rstrip()
        sp = line.split(' ')
        word, vec = sp[0], sp[1:]
        if word in word2idx:
            count += 1
            embedding[word2idx[word]] = np.asarray(vec, dtype='float32') #将词转换成对应的向量
# Out:
# - At line 0
# - At line 100000
# - At line 200000
# - At line 300000

# %% [markdown]
# 现在已经得到每个词索引所对应的向量

# %%
print("[%d / %d] words have found pre-trained values"%(count, len(word2idx)))
np.save('./vocab/word.npy', embedding)
print('Saved ./vocab/word.npy')
# Out:
# [19676 / 20598] words have found pre-trained values
# Saved ./vocab/word.npy

# %% [markdown]
# ### 构建训练数据
#
# - 注意所有的输入样本必须都是相同shape（文本长度，词向量维度等）

# %% [markdown]
# ### 数据生成器
# - tf.data.Dataset.from_tensor_slices(tensor)：将tensor沿其第一个维度切片，返回一个含有N个样本的数据集，这样做的问题就是需要将整个数据集整体传入，然后切片建立数据集类对象，比较占内存。
#
# - tf.data.Dataset.from_generator(data_generator,output_data_type,output_data_shape)：从一个生成器中不断读取样本

# %%
def data_generator(f_path, params):
    with open(f_path,encoding='utf-8') as f:
        print('Reading', f_path)
        for line in f:
            line = line.rstrip()
            label, text = line.split('\t')
            text = text.split(' ')
            x = [params['word2idx'].get(w, len(word2idx)) for w in text]#得到当前词所对应的ID
            if len(x) >= params['max_len']:#截断操作
                x = x[:params['max_len']]
            else:
                x += [0] * (params['max_len'] - len(x))#补齐操作
            y = int(label)
            yield x, y

# %%
def dataset(is_training, params):
    _shapes = ([params['max_len']], ())
    _types = (tf.int32, tf.int32)
  
    if is_training:
        ds = tf.data.Dataset.from_generator(
            lambda: data_generator(params['train_path'], params),
            output_shapes = _shapes,
            output_types = _types,)
        ds = ds.shuffle(params['num_samples'])
        ds = ds.batch(params['batch_size'])
        ds = ds.prefetch(tf.data.experimental.AUTOTUNE)#设置缓存序列，根据可用的CPU动态设置并行调用的数量，说白了就是加速
    else:
        ds = tf.data.Dataset.from_generator(
            lambda: data_generator(params['test_path'], params),
            output_shapes = _shapes,
            output_types = _types,)
        ds = ds.batch(params['batch_size'])
        ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
    return ds

# %% [markdown]
# ### 自定义网络模型
# - 定义好都有哪些层
# - 前向传播走一遍就行了

# %% [markdown]
# embedding_lookup的作用：

# %% [markdown]
# ![title](./img/SentimentAnalysis5.png)

# %% [markdown]
# ![title](./img/SentimentAnalysis16.png)

# %% [markdown]
# ![title](./img/2.png)

# %%
class Model(tf.keras.Model):
    def __init__(self, params):
        super().__init__()
    
        self.embedding = tf.Variable(np.load('./vocab/word.npy'),
                                     dtype=tf.float32,
                                     name='pretrained_embedding',
                                     trainable=False,)

        self.drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop3 = tf.keras.layers.Dropout(params['dropout_rate'])

        self.rnn1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        self.rnn2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        self.rnn3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=False))

        self.drop_fc = tf.keras.layers.Dropout(params['dropout_rate'])
        self.fc = tf.keras.layers.Dense(2*params['rnn_units'], tf.nn.elu)

        self.out_linear = tf.keras.layers.Dense(2)

  
    def call(self, inputs, training=False):
        if inputs.dtype != tf.int32:
            inputs = tf.cast(inputs, tf.int32)
    
        batch_sz = tf.shape(inputs)[0]
        rnn_units = 2*params['rnn_units']

        x = tf.nn.embedding_lookup(self.embedding, inputs)
        
        x = self.drop1(x, training=training)
        x = self.rnn1(x)

        x = self.drop2(x, training=training)
        x = self.rnn2(x)

        x = self.drop3(x, training=training)
        x = self.rnn3(x)

        x = self.drop_fc(x, training=training)
        x = self.fc(x)

        x = self.out_linear(x)

        return x

# %% [markdown]
# 二版本：速度会更快

# %%
class Model(tf.keras.Model):
    def __init__(self, params):
        super().__init__()
    
        self.embedding = tf.Variable(np.load('./vocab/word.npy'),
                                     dtype=tf.float32,
                                     name='pretrained_embedding',
                                     trainable=False,)

        self.drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop3 = tf.keras.layers.Dropout(params['dropout_rate'])

        self.rnn1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        self.rnn2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        self.rnn3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))

        self.drop_fc = tf.keras.layers.Dropout(params['dropout_rate'])
        self.fc = tf.keras.layers.Dense(2*params['rnn_units'], tf.nn.elu)

        self.out_linear = tf.keras.layers.Dense(2)

  
    def call(self, inputs, training=False):
        if inputs.dtype != tf.int32:
            inputs = tf.cast(inputs, tf.int32)
    
        batch_sz = tf.shape(inputs)[0]
        rnn_units = 2*params['rnn_units']

        x = tf.nn.embedding_lookup(self.embedding, inputs)
        
        x = tf.reshape(x, (batch_sz*10*10, 10, 50))
        x = self.drop1(x, training=training)
        x = self.rnn1(x)
        x = tf.reduce_max(x, 1)

        x = tf.reshape(x, (batch_sz*10, 10, rnn_units))
        x = self.drop2(x, training=training)
        x = self.rnn2(x)
        x = tf.reduce_max(x, 1)

        x = tf.reshape(x, (batch_sz, 10, rnn_units))
        x = self.drop3(x, training=training)
        x = self.rnn3(x)
        x = tf.reduce_max(x, 1)

        x = self.drop_fc(x, training=training)
        x = self.fc(x)

        x = self.out_linear(x)

        return x

# %% [markdown]
# ### 设置参数

# %%
params = {
  'vocab_path': './vocab/word.txt',
  'train_path': './data/train.txt',
  'test_path': './data/test.txt',
  'num_samples': 25000,
  'num_labels': 2,
  'batch_size': 32,
  'max_len': 1000,
  'rnn_units': 200,
  'dropout_rate': 0.2,
  'clip_norm': 10.,
  'num_patience': 3,
  'lr': 3e-4,
}

# %% [markdown]
# 用来判断进行提前停止

# %%
def is_descending(history: list):
    history = history[-(params['num_patience']+1):]
    for i in range(1, len(history)):
        if history[i-1] <= history[i]:
            return False
    return True

# %%
word2idx = {}
with open(params['vocab_path'],encoding='utf-8') as f:
    for i, line in enumerate(f):
        line = line.rstrip()
        word2idx[line] = i
params['word2idx'] = word2idx
params['vocab_size'] = len(word2idx) + 1


model = Model(params)
model.build(input_shape=(None, None))#设置输入的大小，或者fit时候也能自动找到
#pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

#链接：https://tensorflow.google.cn/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay?version=stable
#return initial_learning_rate * decay_rate ^ (step / decay_steps)
decay_lr = tf.optimizers.schedules.ExponentialDecay(params['lr'], 1000, 0.95)#相当于加了一个指数衰减函数
optim = tf.optimizers.Adam(params['lr'])
global_step = 0

history_acc = []
best_acc = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

# %%
while True:
  # 训练模型
    for texts, labels in dataset(is_training=True, params=params):
        with tf.GradientTape() as tape:#梯度带，记录所有在上下文中的操作，并且通过调用.gradient()获得任何上下文中计算得出的张量的梯度
            logits = model(texts, training=True)
            loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits)
            loss = tf.reduce_mean(loss)
  
        optim.lr.assign(decay_lr(global_step))
        grads = tape.gradient(loss, model.trainable_variables)
        grads, _ = tf.clip_by_global_norm(grads, params['clip_norm']) #将梯度限制一下，有的时候回更新太猛，防止过拟合
        optim.apply_gradients(zip(grads, model.trainable_variables))#更新梯度

        if global_step % 50 == 0:
            logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
                global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
            t0 = time.time()
        global_step += 1

    # 验证集效果
    m = tf.keras.metrics.Accuracy()

    for texts, labels in dataset(is_training=False, params=params):
        logits = model(texts, training=False)
        y_pred = tf.argmax(logits, axis=-1)
        m.update_state(y_true=labels, y_pred=y_pred)
    
    acc = m.result().numpy()
    logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))
    history_acc.append(acc)
  
    if acc > best_acc:
        best_acc = acc
    logger.info("Best Accuracy: {:.3f}".format(best_acc))
  
    if len(history_acc) > params['num_patience'] and is_descending(history_acc):
        logger.info("Testing Accuracy not improved over {} epochs, Early Stop".format(params['num_patience']))
        break
# Out:
# Reading ./data/train.txt
# INFO:tensorflow:Step 0 | Loss: 0.6845 | Spent: 17.0 secs | LR: 0.000300
# INFO:tensorflow:Step 50 | Loss: 0.6503 | Spent: 2.6 secs | LR: 0.000299
# INFO:tensorflow:Step 100 | Loss: 0.7239 | Spent: 2.5 secs | LR: 0.000298
# INFO:tensorflow:Step 150 | Loss: 0.4704 | Spent: 2.5 secs | LR: 0.000298
# INFO:tensorflow:Step 200 | Loss: 0.6338 | Spent: 2.5 secs | LR: 0.000297
# INFO:tensorflow:Step 250 | Loss: 0.6943 | Spent: 2.5 secs | LR: 0.000296
# INFO:tensorflow:Step 300 | Loss: 0.4189 | Spent: 2.5 secs | LR: 0.000295
# INFO:tensorflow:Step 350 | Loss: 0.7950 | Spent: 2.5 secs | LR: 0.000295
# INFO:tensorflow:Step 400 | Loss: 0.4195 | Spent: 2.5 secs | LR: 0.000294
# INFO:tensorflow:Step 450 | Loss: 0.6086 | Spent: 2.5 secs | LR: 0.000293
# INFO:tensorflow:Step 500 | Loss: 0.4783 | Spent: 2.5 secs | LR: 0.000292
# INFO:tensorflow:Step 550 | Loss: 0.7248 | Spent: 2.5 secs | LR: 0.000292
# INFO:tensorflow:Step 600 | Loss: 0.4796 | Spent: 2.6 secs | LR: 0.000291
# INFO:tensorflow:Step 650 | Loss: 0.3614 | Spent: 2.5 secs | LR: 0.000290
# INFO:tensorflow:Step 700 | Loss: 0.4536 | Spent: 2.5 secs | LR: 0.000289
# INFO:tensorflow:Step 750 | Loss: 0.4465 | Spent: 2.5 secs | LR: 0.000289
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.814
# INFO:tensorflow:Best Accuracy: 0.814
# Reading ./data/train.txt
# INFO:tensorflow:Step 800 | Loss: 0.4106 | Spent: 50.2 secs | LR: 0.000288
# INFO:tensorflow:Step 850 | Loss: 0.4304 | Spent: 2.6 secs | LR: 0.000287
# INFO:tensorflow:Step 900 | Loss: 0.7140 | Spent: 2.6 secs | LR: 0.000286
# INFO:tensorflow:Step 950 | Loss: 0.3375 | Spent: 2.5 secs | LR: 0.000286
# INFO:tensorflow:Step 1000 | Loss: 0.3629 | Spent: 2.5 secs | LR: 0.000285
# INFO:tensorflow:Step 1050 | Loss: 0.4125 | Spent: 2.5 secs | LR: 0.000284
# INFO:tensorflow:Step 1100 | Loss: 0.4709 | Spent: 2.5 secs | LR: 0.000284
# INFO:tensorflow:Step 1150 | Loss: 0.2876 | Spent: 2.5 secs | LR: 0.000283
# INFO:tensorflow:Step 1200 | Loss: 0.2558 | Spent: 2.5 secs | LR: 0.000282
# INFO:tensorflow:Step 1250 | Loss: 0.7509 | Spent: 2.5 secs | LR: 0.000281
# INFO:tensorflow:Step 1300 | Loss: 0.3683 | Spent: 2.5 secs | LR: 0.000281
# INFO:tensorflow:Step 1350 | Loss: 0.3405 | Spent: 2.6 secs | LR: 0.000280
# INFO:tensorflow:Step 1400 | Loss: 0.1750 | Spent: 2.6 secs | LR: 0.000279
# INFO:tensorflow:Step 1450 | Loss: 0.3411 | Spent: 2.5 secs | LR: 0.000278
# INFO:tensorflow:Step 1500 | Loss: 0.6021 | Spent: 2.5 secs | LR: 0.000278
# INFO:tensorflow:Step 1550 | Loss: 0.3337 | Spent: 2.6 secs | LR: 0.000277
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.838
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ./data/train.txt
# INFO:tensorflow:Step 1600 | Loss: 0.4501 | Spent: 49.8 secs | LR: 0.000276
# INFO:tensorflow:Step 1650 | Loss: 0.4674 | Spent: 2.5 secs | LR: 0.000276
# INFO:tensorflow:Step 1700 | Loss: 0.3515 | Spent: 2.5 secs | LR: 0.000275
# INFO:tensorflow:Step 1750 | Loss: 0.4268 | Spent: 2.5 secs | LR: 0.000274
# INFO:tensorflow:Step 1800 | Loss: 0.3070 | Spent: 2.5 secs | LR: 0.000274
# INFO:tensorflow:Step 1850 | Loss: 0.4112 | Spent: 2.5 secs | LR: 0.000273
# INFO:tensorflow:Step 1900 | Loss: 0.2679 | Spent: 2.5 secs | LR: 0.000272
# INFO:tensorflow:Step 1950 | Loss: 0.3377 | Spent: 2.5 secs | LR: 0.000271
# INFO:tensorflow:Step 2000 | Loss: 0.5412 | Spent: 2.5 secs | LR: 0.000271
# INFO:tensorflow:Step 2050 | Loss: 0.3565 | Spent: 2.5 secs | LR: 0.000270
# INFO:tensorflow:Step 2100 | Loss: 0.1735 | Spent: 2.5 secs | LR: 0.000269
# INFO:tensorflow:Step 2150 | Loss: 0.3049 | Spent: 2.5 secs | LR: 0.000269
# INFO:tensorflow:Step 2200 | Loss: 0.3215 | Spent: 2.5 secs | LR: 0.000268
# INFO:tensorflow:Step 2250 | Loss: 0.3436 | Spent: 2.5 secs | LR: 0.000267
# INFO:tensorflow:Step 2300 | Loss: 0.3026 | Spent: 2.5 secs | LR: 0.000267
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.829
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ./data/train.txt
# INFO:tensorflow:Step 2350 | Loss: 0.3053 | Spent: 50.4 secs | LR: 0.000266
# INFO:tensorflow:Step 2400 | Loss: 0.5189 | Spent: 2.5 secs | LR: 0.000265
# INFO:tensorflow:Step 2450 | Loss: 0.3222 | Spent: 2.5 secs | LR: 0.000265
# INFO:tensorflow:Step 2500 | Loss: 0.3286 | Spent: 2.5 secs | LR: 0.000264
# INFO:tensorflow:Step 2550 | Loss: 0.4674 | Spent: 2.5 secs | LR: 0.000263
# INFO:tensorflow:Step 2600 | Loss: 0.4433 | Spent: 2.6 secs | LR: 0.000263
# INFO:tensorflow:Step 2650 | Loss: 0.6293 | Spent: 2.5 secs | LR: 0.000262
# INFO:tensorflow:Step 2700 | Loss: 0.3819 | Spent: 2.5 secs | LR: 0.000261
# INFO:tensorflow:Step 2750 | Loss: 0.2632 | Spent: 2.5 secs | LR: 0.000261
# INFO:tensorflow:Step 2800 | Loss: 0.3304 | Spent: 2.5 secs | LR: 0.000260
# INFO:tensorflow:Step 2850 | Loss: 0.3420 | Spent: 2.5 secs | LR: 0.000259
# INFO:tensorflow:Step 2900 | Loss: 0.1919 | Spent: 2.5 secs | LR: 0.000259
# INFO:tensorflow:Step 2950 | Loss: 0.4448 | Spent: 2.5 secs | LR: 0.000258
# INFO:tensorflow:Step 3000 | Loss: 0.3111 | Spent: 2.6 secs | LR: 0.000257
# INFO:tensorflow:Step 3050 | Loss: 0.2723 | Spent: 2.6 secs | LR: 0.000257
# INFO:tensorflow:Step 3100 | Loss: 0.3349 | Spent: 2.6 secs | LR: 0.000256
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.854
# INFO:tensorflow:Best Accuracy: 0.854
# Reading ./data/train.txt
# INFO:tensorflow:Step 3150 | Loss: 0.4132 | Spent: 49.7 secs | LR: 0.000255
# INFO:tensorflow:Step 3200 | Loss: 0.2976 | Spent: 2.5 secs | LR: 0.000255
# INFO:tensorflow:Step 3250 | Loss: 0.2877 | Spent: 2.5 secs | LR: 0.000254
# INFO:tensorflow:Step 3300 | Loss: 0.2166 | Spent: 2.5 secs | LR: 0.000253
# INFO:tensorflow:Step 3350 | Loss: 0.3684 | Spent: 2.6 secs | LR: 0.000253
# INFO:tensorflow:Step 3400 | Loss: 0.2603 | Spent: 2.5 secs | LR: 0.000252
# INFO:tensorflow:Step 3450 | Loss: 0.3688 | Spent: 2.5 secs | LR: 0.000251
# INFO:tensorflow:Step 3500 | Loss: 0.2437 | Spent: 2.5 secs | LR: 0.000251
# INFO:tensorflow:Step 3550 | Loss: 0.2755 | Spent: 2.5 secs | LR: 0.000250
# INFO:tensorflow:Step 3600 | Loss: 0.3630 | Spent: 2.5 secs | LR: 0.000249
# INFO:tensorflow:Step 3650 | Loss: 0.3344 | Spent: 2.5 secs | LR: 0.000249
# INFO:tensorflow:Step 3700 | Loss: 0.3320 | Spent: 2.5 secs | LR: 0.000248
# INFO:tensorflow:Step 3750 | Loss: 0.2922 | Spent: 2.5 secs | LR: 0.000248
# INFO:tensorflow:Step 3800 | Loss: 0.2857 | Spent: 2.5 secs | LR: 0.000247
# INFO:tensorflow:Step 3850 | Loss: 0.3411 | Spent: 2.6 secs | LR: 0.000246
# INFO:tensorflow:Step 3900 | Loss: 0.1700 | Spent: 2.5 secs | LR: 0.000246
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.860
# INFO:tensorflow:Best Accuracy: 0.860
# Reading ./data/train.txt
# INFO:tensorflow:Step 3950 | Loss: 0.5861 | Spent: 50.1 secs | LR: 0.000245
# INFO:tensorflow:Step 4000 | Loss: 0.2969 | Spent: 2.5 secs | LR: 0.000244
# INFO:tensorflow:Step 4050 | Loss: 0.2641 | Spent: 2.5 secs | LR: 0.000244
# INFO:tensorflow:Step 4100 | Loss: 0.3675 | Spent: 2.5 secs | LR: 0.000243
# INFO:tensorflow:Step 4150 | Loss: 0.2572 | Spent: 2.5 secs | LR: 0.000242
# INFO:tensorflow:Step 4200 | Loss: 0.5350 | Spent: 2.5 secs | LR: 0.000242
# INFO:tensorflow:Step 4250 | Loss: 0.4264 | Spent: 2.6 secs | LR: 0.000241
# INFO:tensorflow:Step 4300 | Loss: 0.4729 | Spent: 2.5 secs | LR: 0.000241
# INFO:tensorflow:Step 4350 | Loss: 0.3697 | Spent: 2.6 secs | LR: 0.000240
# INFO:tensorflow:Step 4400 | Loss: 0.3150 | Spent: 2.5 secs | LR: 0.000239
# INFO:tensorflow:Step 4450 | Loss: 0.4236 | Spent: 2.6 secs | LR: 0.000239
# INFO:tensorflow:Step 4500 | Loss: 0.4455 | Spent: 2.6 secs | LR: 0.000238
# INFO:tensorflow:Step 4550 | Loss: 0.2918 | Spent: 2.6 secs | LR: 0.000238
# INFO:tensorflow:Step 4600 | Loss: 0.3460 | Spent: 2.5 secs | LR: 0.000237
# INFO:tensorflow:Step 4650 | Loss: 0.2831 | Spent: 2.6 secs | LR: 0.000236
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.852
# INFO:tensorflow:Best Accuracy: 0.860
# Reading ./data/train.txt
# INFO:tensorflow:Step 4700 | Loss: 0.2974 | Spent: 49.8 secs | LR: 0.000236
# INFO:tensorflow:Step 4750 | Loss: 0.5020 | Spent: 2.5 secs | LR: 0.000235
# INFO:tensorflow:Step 4800 | Loss: 0.3690 | Spent: 2.6 secs | LR: 0.000235
# INFO:tensorflow:Step 4850 | Loss: 0.5238 | Spent: 2.6 secs | LR: 0.000234
# INFO:tensorflow:Step 4900 | Loss: 0.2860 | Spent: 2.5 secs | LR: 0.000233
# INFO:tensorflow:Step 4950 | Loss: 0.3537 | Spent: 2.6 secs | LR: 0.000233
# INFO:tensorflow:Step 5000 | Loss: 0.2991 | Spent: 2.6 secs | LR: 0.000232
# INFO:tensorflow:Step 5050 | Loss: 0.5919 | Spent: 2.6 secs | LR: 0.000232
# INFO:tensorflow:Step 5100 | Loss: 0.2370 | Spent: 2.6 secs | LR: 0.000231
# INFO:tensorflow:Step 5150 | Loss: 0.2830 | Spent: 2.6 secs | LR: 0.000230
# INFO:tensorflow:Step 5200 | Loss: 0.4185 | Spent: 2.5 secs | LR: 0.000230
# INFO:tensorflow:Step 5250 | Loss: 0.2651 | Spent: 2.6 secs | LR: 0.000229
# INFO:tensorflow:Step 5300 | Loss: 0.2399 | Spent: 2.5 secs | LR: 0.000229
# INFO:tensorflow:Step 5350 | Loss: 0.3068 | Spent: 2.6 secs | LR: 0.000228
# INFO:tensorflow:Step 5400 | Loss: 0.2000 | Spent: 2.5 secs | LR: 0.000227
# INFO:tensorflow:Step 5450 | Loss: 0.1464 | Spent: 2.5 secs | LR: 0.000227
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.870
# INFO:tensorflow:Best Accuracy: 0.870
# Reading ./data/train.txt
# INFO:tensorflow:Step 5500 | Loss: 0.4301 | Spent: 50.7 secs | LR: 0.000226
# INFO:tensorflow:Step 5550 | Loss: 0.3893 | Spent: 2.5 secs | LR: 0.000226
# INFO:tensorflow:Step 5600 | Loss: 0.3978 | Spent: 2.5 secs | LR: 0.000225
# INFO:tensorflow:Step 5650 | Loss: 0.2152 | Spent: 2.5 secs | LR: 0.000225
# INFO:tensorflow:Step 5700 | Loss: 0.2819 | Spent: 2.5 secs | LR: 0.000224
# INFO:tensorflow:Step 5750 | Loss: 0.2730 | Spent: 2.5 secs | LR: 0.000223
# INFO:tensorflow:Step 5800 | Loss: 0.1432 | Spent: 2.5 secs | LR: 0.000223
# INFO:tensorflow:Step 5850 | Loss: 0.1622 | Spent: 2.6 secs | LR: 0.000222
# INFO:tensorflow:Step 5900 | Loss: 0.2546 | Spent: 2.5 secs | LR: 0.000222
# INFO:tensorflow:Step 5950 | Loss: 0.2952 | Spent: 2.5 secs | LR: 0.000221
# INFO:tensorflow:Step 6000 | Loss: 0.1548 | Spent: 2.5 secs | LR: 0.000221
# INFO:tensorflow:Step 6050 | Loss: 0.1580 | Spent: 2.5 secs | LR: 0.000220
# INFO:tensorflow:Step 6100 | Loss: 0.2940 | Spent: 2.6 secs | LR: 0.000219
# INFO:tensorflow:Step 6150 | Loss: 0.2173 | Spent: 2.5 secs | LR: 0.000219
# INFO:tensorflow:Step 6200 | Loss: 0.2130 | Spent: 2.5 secs | LR: 0.000218
# INFO:tensorflow:Step 6250 | Loss: 0.3969 | Spent: 2.6 secs | LR: 0.000218
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.865
# INFO:tensorflow:Best Accuracy: 0.870
# Reading ./data/train.txt
# INFO:tensorflow:Step 6300 | Loss: 0.1556 | Spent: 50.3 secs | LR: 0.000217
# INFO:tensorflow:Step 6350 | Loss: 0.2805 | Spent: 2.5 secs | LR: 0.000217
# INFO:tensorflow:Step 6400 | Loss: 0.2782 | Spent: 2.5 secs | LR: 0.000216
# INFO:tensorflow:Step 6450 | Loss: 0.1360 | Spent: 2.5 secs | LR: 0.000215
# INFO:tensorflow:Step 6500 | Loss: 0.3203 | Spent: 2.5 secs | LR: 0.000215
# INFO:tensorflow:Step 6550 | Loss: 0.3791 | Spent: 2.5 secs | LR: 0.000214
# INFO:tensorflow:Step 6600 | Loss: 0.3536 | Spent: 2.5 secs | LR: 0.000214
# INFO:tensorflow:Step 6650 | Loss: 0.2962 | Spent: 2.6 secs | LR: 0.000213
# INFO:tensorflow:Step 6700 | Loss: 0.3482 | Spent: 2.6 secs | LR: 0.000213
# INFO:tensorflow:Step 6750 | Loss: 0.2242 | Spent: 2.5 secs | LR: 0.000212
# INFO:tensorflow:Step 6800 | Loss: 0.2569 | Spent: 2.5 secs | LR: 0.000212
# INFO:tensorflow:Step 6850 | Loss: 0.2806 | Spent: 2.5 secs | LR: 0.000211
# INFO:tensorflow:Step 6900 | Loss: 0.5990 | Spent: 2.6 secs | LR: 0.000211
# INFO:tensorflow:Step 6950 | Loss: 0.2154 | Spent: 2.6 secs | LR: 0.000210
# INFO:tensorflow:Step 7000 | Loss: 0.3111 | Spent: 2.6 secs | LR: 0.000210
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.875
# INFO:tensorflow:Best Accuracy: 0.875
# Reading ./data/train.txt
# INFO:tensorflow:Step 7050 | Loss: 0.2406 | Spent: 50.4 secs | LR: 0.000209
# INFO:tensorflow:Step 7100 | Loss: 0.2972 | Spent: 2.6 secs | LR: 0.000208
# INFO:tensorflow:Step 7150 | Loss: 0.2459 | Spent: 2.6 secs | LR: 0.000208
# INFO:tensorflow:Step 7200 | Loss: 0.2280 | Spent: 2.6 secs | LR: 0.000207
# INFO:tensorflow:Step 7250 | Loss: 0.2086 | Spent: 2.6 secs | LR: 0.000207
# INFO:tensorflow:Step 7300 | Loss: 0.3858 | Spent: 2.6 secs | LR: 0.000206
# INFO:tensorflow:Step 7350 | Loss: 0.3213 | Spent: 2.5 secs | LR: 0.000206
# INFO:tensorflow:Step 7400 | Loss: 0.3121 | Spent: 2.6 secs | LR: 0.000205
# INFO:tensorflow:Step 7450 | Loss: 0.3301 | Spent: 2.6 secs | LR: 0.000205
# INFO:tensorflow:Step 7500 | Loss: 0.3081 | Spent: 2.6 secs | LR: 0.000204
# INFO:tensorflow:Step 7550 | Loss: 0.2012 | Spent: 2.5 secs | LR: 0.000204
# INFO:tensorflow:Step 7600 | Loss: 0.3313 | Spent: 2.6 secs | LR: 0.000203
# INFO:tensorflow:Step 7650 | Loss: 0.2739 | Spent: 2.6 secs | LR: 0.000203
# INFO:tensorflow:Step 7700 | Loss: 0.2515 | Spent: 2.6 secs | LR: 0.000202
# INFO:tensorflow:Step 7750 | Loss: 0.3167 | Spent: 2.6 secs | LR: 0.000202
# INFO:tensorflow:Step 7800 | Loss: 0.3665 | Spent: 2.6 secs | LR: 0.000201
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.876
# INFO:tensorflow:Best Accuracy: 0.876
# Reading ./data/train.txt
# INFO:tensorflow:Step 7850 | Loss: 0.1721 | Spent: 45.0 secs | LR: 0.000201
# INFO:tensorflow:Step 7900 | Loss: 0.1176 | Spent: 2.6 secs | LR: 0.000200
# INFO:tensorflow:Step 7950 | Loss: 0.1893 | Spent: 2.6 secs | LR: 0.000200
# INFO:tensorflow:Step 8000 | Loss: 0.2639 | Spent: 2.6 secs | LR: 0.000199
# INFO:tensorflow:Step 8050 | Loss: 0.1783 | Spent: 2.5 secs | LR: 0.000199
# INFO:tensorflow:Step 8100 | Loss: 0.3218 | Spent: 2.6 secs | LR: 0.000198
# INFO:tensorflow:Step 8150 | Loss: 0.3051 | Spent: 2.6 secs | LR: 0.000198
# INFO:tensorflow:Step 8200 | Loss: 0.1853 | Spent: 2.5 secs | LR: 0.000197
# INFO:tensorflow:Step 8250 | Loss: 0.2909 | Spent: 2.5 secs | LR: 0.000196
# INFO:tensorflow:Step 8300 | Loss: 0.3012 | Spent: 2.5 secs | LR: 0.000196
# INFO:tensorflow:Step 8350 | Loss: 0.1663 | Spent: 2.6 secs | LR: 0.000195
# INFO:tensorflow:Step 8400 | Loss: 0.1380 | Spent: 2.6 secs | LR: 0.000195
# INFO:tensorflow:Step 8450 | Loss: 0.3655 | Spent: 2.6 secs | LR: 0.000194
# INFO:tensorflow:Step 8500 | Loss: 0.2860 | Spent: 2.6 secs | LR: 0.000194
# INFO:tensorflow:Step 8550 | Loss: 0.5291 | Spent: 2.6 secs | LR: 0.000193
# INFO:tensorflow:Step 8600 | Loss: 0.3539 | Spent: 2.5 secs | LR: 0.000193
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.868
# INFO:tensorflow:Best Accuracy: 0.876
# Reading ./data/train.txt
# INFO:tensorflow:Step 8650 | Loss: 0.2566 | Spent: 49.8 secs | LR: 0.000192
# INFO:tensorflow:Step 8700 | Loss: 0.3931 | Spent: 2.5 secs | LR: 0.000192
# INFO:tensorflow:Step 8750 | Loss: 0.2780 | Spent: 2.5 secs | LR: 0.000192
# INFO:tensorflow:Step 8800 | Loss: 0.6813 | Spent: 2.6 secs | LR: 0.000191
# INFO:tensorflow:Step 8850 | Loss: 0.1311 | Spent: 2.6 secs | LR: 0.000191
# INFO:tensorflow:Step 8900 | Loss: 0.3303 | Spent: 2.6 secs | LR: 0.000190
# INFO:tensorflow:Step 8950 | Loss: 0.2167 | Spent: 2.6 secs | LR: 0.000190
# INFO:tensorflow:Step 9000 | Loss: 0.3204 | Spent: 2.5 secs | LR: 0.000189
# INFO:tensorflow:Step 9050 | Loss: 0.1399 | Spent: 2.6 secs | LR: 0.000189
# INFO:tensorflow:Step 9100 | Loss: 0.2164 | Spent: 2.5 secs | LR: 0.000188
# INFO:tensorflow:Step 9150 | Loss: 0.2144 | Spent: 2.5 secs | LR: 0.000188
# INFO:tensorflow:Step 9200 | Loss: 0.2734 | Spent: 2.5 secs | LR: 0.000187
# INFO:tensorflow:Step 9250 | Loss: 0.2905 | Spent: 2.6 secs | LR: 0.000187
# INFO:tensorflow:Step 9300 | Loss: 0.3785 | Spent: 2.6 secs | LR: 0.000186
# INFO:tensorflow:Step 9350 | Loss: 0.1574 | Spent: 2.5 secs | LR: 0.000186
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.874
# INFO:tensorflow:Best Accuracy: 0.876
# Reading ./data/train.txt
# INFO:tensorflow:Step 9400 | Loss: 0.3294 | Spent: 43.3 secs | LR: 0.000185
# INFO:tensorflow:Step 9450 | Loss: 0.2285 | Spent: 2.5 secs | LR: 0.000185
# INFO:tensorflow:Step 9500 | Loss: 0.2604 | Spent: 2.6 secs | LR: 0.000184
# INFO:tensorflow:Step 9550 | Loss: 0.1325 | Spent: 2.5 secs | LR: 0.000184
# INFO:tensorflow:Step 9600 | Loss: 0.2607 | Spent: 2.6 secs | LR: 0.000183
# INFO:tensorflow:Step 9650 | Loss: 0.2230 | Spent: 2.5 secs | LR: 0.000183
# INFO:tensorflow:Step 9700 | Loss: 0.2422 | Spent: 2.6 secs | LR: 0.000182
# INFO:tensorflow:Step 9750 | Loss: 0.2603 | Spent: 2.5 secs | LR: 0.000182
# INFO:tensorflow:Step 9800 | Loss: 0.1723 | Spent: 2.6 secs | LR: 0.000181
# INFO:tensorflow:Step 9850 | Loss: 0.3318 | Spent: 2.6 secs | LR: 0.000181
# INFO:tensorflow:Step 9900 | Loss: 0.2816 | Spent: 2.5 secs | LR: 0.000181
# INFO:tensorflow:Step 9950 | Loss: 0.2486 | Spent: 2.6 secs | LR: 0.000180
# INFO:tensorflow:Step 10000 | Loss: 0.4722 | Spent: 2.5 secs | LR: 0.000180
# INFO:tensorflow:Step 10050 | Loss: 0.3312 | Spent: 2.5 secs | LR: 0.000179
# INFO:tensorflow:Step 10100 | Loss: 0.2541 | Spent: 2.5 secs | LR: 0.000179
# INFO:tensorflow:Step 10150 | Loss: 0.3270 | Spent: 2.6 secs | LR: 0.000178
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.871
# INFO:tensorflow:Best Accuracy: 0.876
# Reading ./data/train.txt
# INFO:tensorflow:Step 10200 | Loss: 0.2490 | Spent: 50.5 secs | LR: 0.000178
# INFO:tensorflow:Step 10250 | Loss: 0.2019 | Spent: 2.6 secs | LR: 0.000177
# INFO:tensorflow:Step 10300 | Loss: 0.4463 | Spent: 2.6 secs | LR: 0.000177
# INFO:tensorflow:Step 10350 | Loss: 0.2148 | Spent: 2.6 secs | LR: 0.000176
# INFO:tensorflow:Step 10400 | Loss: 0.4027 | Spent: 2.6 secs | LR: 0.000176
# INFO:tensorflow:Step 10450 | Loss: 0.2062 | Spent: 2.5 secs | LR: 0.000176
# INFO:tensorflow:Step 10500 | Loss: 0.1639 | Spent: 2.5 secs | LR: 0.000175
# INFO:tensorflow:Step 10550 | Loss: 0.1305 | Spent: 2.6 secs | LR: 0.000175
# INFO:tensorflow:Step 10600 | Loss: 0.1731 | Spent: 2.6 secs | LR: 0.000174
# INFO:tensorflow:Step 10650 | Loss: 0.2954 | Spent: 2.6 secs | LR: 0.000174
# INFO:tensorflow:Step 10700 | Loss: 0.2237 | Spent: 2.6 secs | LR: 0.000173
# INFO:tensorflow:Step 10750 | Loss: 0.3685 | Spent: 2.6 secs | LR: 0.000173
# INFO:tensorflow:Step 10800 | Loss: 0.2596 | Spent: 2.5 secs | LR: 0.000172
# INFO:tensorflow:Step 10850 | Loss: 0.2244 | Spent: 2.5 secs | LR: 0.000172
# INFO:tensorflow:Step 10900 | Loss: 0.4911 | Spent: 2.6 secs | LR: 0.000172
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.880
# INFO:tensorflow:Best Accuracy: 0.880
# Reading ./data/train.txt
# INFO:tensorflow:Step 10950 | Loss: 0.4746 | Spent: 50.3 secs | LR: 0.000171
# INFO:tensorflow:Step 11000 | Loss: 0.0888 | Spent: 2.5 secs | LR: 0.000171
# INFO:tensorflow:Step 11050 | Loss: 0.4155 | Spent: 2.6 secs | LR: 0.000170
# INFO:tensorflow:Step 11100 | Loss: 0.2325 | Spent: 2.7 secs | LR: 0.000170
# INFO:tensorflow:Step 11150 | Loss: 0.2653 | Spent: 2.6 secs | LR: 0.000169
# INFO:tensorflow:Step 11200 | Loss: 0.1204 | Spent: 2.6 secs | LR: 0.000169
# INFO:tensorflow:Step 11250 | Loss: 0.2595 | Spent: 2.5 secs | LR: 0.000168
# INFO:tensorflow:Step 11300 | Loss: 0.2958 | Spent: 2.6 secs | LR: 0.000168
# INFO:tensorflow:Step 11350 | Loss: 0.1926 | Spent: 2.5 secs | LR: 0.000168
# INFO:tensorflow:Step 11400 | Loss: 0.2065 | Spent: 2.6 secs | LR: 0.000167
# INFO:tensorflow:Step 11450 | Loss: 0.2659 | Spent: 2.6 secs | LR: 0.000167
# INFO:tensorflow:Step 11500 | Loss: 0.1362 | Spent: 2.6 secs | LR: 0.000166
# INFO:tensorflow:Step 11550 | Loss: 0.4005 | Spent: 2.6 secs | LR: 0.000166
# INFO:tensorflow:Step 11600 | Loss: 0.2477 | Spent: 2.6 secs | LR: 0.000165
# INFO:tensorflow:Step 11650 | Loss: 0.0942 | Spent: 2.6 secs | LR: 0.000165
# INFO:tensorflow:Step 11700 | Loss: 0.1921 | Spent: 2.6 secs | LR: 0.000165
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.882
# INFO:tensorflow:Best Accuracy: 0.882
# Reading ./data/train.txt
# INFO:tensorflow:Step 11750 | Loss: 0.2239 | Spent: 50.3 secs | LR: 0.000164
# INFO:tensorflow:Step 11800 | Loss: 0.4326 | Spent: 2.6 secs | LR: 0.000164
# INFO:tensorflow:Step 11850 | Loss: 0.2249 | Spent: 2.5 secs | LR: 0.000163
# INFO:tensorflow:Step 11900 | Loss: 0.2538 | Spent: 2.5 secs | LR: 0.000163
# INFO:tensorflow:Step 11950 | Loss: 0.4501 | Spent: 2.5 secs | LR: 0.000163
# INFO:tensorflow:Step 12000 | Loss: 0.1000 | Spent: 2.6 secs | LR: 0.000162
# INFO:tensorflow:Step 12050 | Loss: 0.5736 | Spent: 2.6 secs | LR: 0.000162
# INFO:tensorflow:Step 12100 | Loss: 0.3302 | Spent: 2.5 secs | LR: 0.000161
# INFO:tensorflow:Step 12150 | Loss: 0.1494 | Spent: 2.6 secs | LR: 0.000161
# INFO:tensorflow:Step 12200 | Loss: 0.4974 | Spent: 2.5 secs | LR: 0.000160
# INFO:tensorflow:Step 12250 | Loss: 0.1974 | Spent: 2.5 secs | LR: 0.000160
# INFO:tensorflow:Step 12300 | Loss: 0.4217 | Spent: 2.5 secs | LR: 0.000160
# INFO:tensorflow:Step 12350 | Loss: 0.0872 | Spent: 2.5 secs | LR: 0.000159
# INFO:tensorflow:Step 12400 | Loss: 0.1847 | Spent: 2.6 secs | LR: 0.000159
# INFO:tensorflow:Step 12450 | Loss: 0.0948 | Spent: 2.5 secs | LR: 0.000158
# INFO:tensorflow:Step 12500 | Loss: 0.2388 | Spent: 2.5 secs | LR: 0.000158
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.862
# INFO:tensorflow:Best Accuracy: 0.882
# Reading ./data/train.txt
# INFO:tensorflow:Step 12550 | Loss: 0.1755 | Spent: 50.0 secs | LR: 0.000158
# INFO:tensorflow:Step 12600 | Loss: 0.4465 | Spent: 2.5 secs | LR: 0.000157
# INFO:tensorflow:Step 12650 | Loss: 0.1773 | Spent: 2.6 secs | LR: 0.000157
# INFO:tensorflow:Step 12700 | Loss: 0.2737 | Spent: 2.6 secs | LR: 0.000156
# INFO:tensorflow:Step 12750 | Loss: 0.2413 | Spent: 2.6 secs | LR: 0.000156
# INFO:tensorflow:Step 12800 | Loss: 0.1669 | Spent: 2.6 secs | LR: 0.000156
# INFO:tensorflow:Step 12850 | Loss: 0.1584 | Spent: 2.5 secs | LR: 0.000155
# INFO:tensorflow:Step 12900 | Loss: 0.2224 | Spent: 2.5 secs | LR: 0.000155
# INFO:tensorflow:Step 12950 | Loss: 0.3611 | Spent: 2.6 secs | LR: 0.000154
# INFO:tensorflow:Step 13000 | Loss: 0.2841 | Spent: 2.5 secs | LR: 0.000154
# INFO:tensorflow:Step 13050 | Loss: 0.3349 | Spent: 2.6 secs | LR: 0.000154
# INFO:tensorflow:Step 13100 | Loss: 0.3812 | Spent: 2.5 secs | LR: 0.000153
# INFO:tensorflow:Step 13150 | Loss: 0.4983 | Spent: 2.5 secs | LR: 0.000153
# INFO:tensorflow:Step 13200 | Loss: 0.5471 | Spent: 2.6 secs | LR: 0.000152
# INFO:tensorflow:Step 13250 | Loss: 0.2722 | Spent: 2.6 secs | LR: 0.000152
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.884
# Reading ./data/train.txt
# INFO:tensorflow:Step 13300 | Loss: 0.2071 | Spent: 50.3 secs | LR: 0.000152
# INFO:tensorflow:Step 13350 | Loss: 0.3685 | Spent: 2.6 secs | LR: 0.000151
# INFO:tensorflow:Step 13400 | Loss: 0.1902 | Spent: 2.6 secs | LR: 0.000151
# INFO:tensorflow:Step 13450 | Loss: 0.2891 | Spent: 2.5 secs | LR: 0.000150
# INFO:tensorflow:Step 13500 | Loss: 0.3239 | Spent: 2.5 secs | LR: 0.000150
# INFO:tensorflow:Step 13550 | Loss: 0.2422 | Spent: 2.6 secs | LR: 0.000150
# INFO:tensorflow:Step 13600 | Loss: 0.0847 | Spent: 2.6 secs | LR: 0.000149
# INFO:tensorflow:Step 13650 | Loss: 0.3238 | Spent: 2.6 secs | LR: 0.000149
# INFO:tensorflow:Step 13700 | Loss: 0.2084 | Spent: 2.6 secs | LR: 0.000149
# INFO:tensorflow:Step 13750 | Loss: 0.0802 | Spent: 2.6 secs | LR: 0.000148
# INFO:tensorflow:Step 13800 | Loss: 0.1451 | Spent: 2.6 secs | LR: 0.000148
# INFO:tensorflow:Step 13850 | Loss: 0.2860 | Spent: 2.6 secs | LR: 0.000147
# INFO:tensorflow:Step 13900 | Loss: 0.1569 | Spent: 2.5 secs | LR: 0.000147
# INFO:tensorflow:Step 13950 | Loss: 0.1756 | Spent: 2.6 secs | LR: 0.000147
# INFO:tensorflow:Step 14000 | Loss: 0.1236 | Spent: 2.6 secs | LR: 0.000146
# INFO:tensorflow:Step 14050 | Loss: 0.2057 | Spent: 2.5 secs | LR: 0.000146
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.883
# INFO:tensorflow:Best Accuracy: 0.884
# Reading ./data/train.txt
# INFO:tensorflow:Step 14100 | Loss: 0.0792 | Spent: 50.7 secs | LR: 0.000146
# INFO:tensorflow:Step 14150 | Loss: 0.1125 | Spent: 2.5 secs | LR: 0.000145
# INFO:tensorflow:Step 14200 | Loss: 0.1738 | Spent: 2.6 secs | LR: 0.000145
# INFO:tensorflow:Step 14250 | Loss: 0.1142 | Spent: 2.6 secs | LR: 0.000144
# INFO:tensorflow:Step 14300 | Loss: 0.2216 | Spent: 2.6 secs | LR: 0.000144
# INFO:tensorflow:Step 14350 | Loss: 0.1844 | Spent: 2.6 secs | LR: 0.000144
# INFO:tensorflow:Step 14400 | Loss: 0.1923 | Spent: 2.5 secs | LR: 0.000143
# INFO:tensorflow:Step 14450 | Loss: 0.2764 | Spent: 2.6 secs | LR: 0.000143
# INFO:tensorflow:Step 14500 | Loss: 0.2215 | Spent: 2.6 secs | LR: 0.000143
# INFO:tensorflow:Step 14550 | Loss: 0.2274 | Spent: 2.6 secs | LR: 0.000142
# INFO:tensorflow:Step 14600 | Loss: 0.3902 | Spent: 2.6 secs | LR: 0.000142
# INFO:tensorflow:Step 14650 | Loss: 0.1348 | Spent: 2.5 secs | LR: 0.000142
# INFO:tensorflow:Step 14700 | Loss: 0.2899 | Spent: 2.5 secs | LR: 0.000141
# INFO:tensorflow:Step 14750 | Loss: 0.3900 | Spent: 2.6 secs | LR: 0.000141
# INFO:tensorflow:Step 14800 | Loss: 0.2443 | Spent: 2.6 secs | LR: 0.000140
# INFO:tensorflow:Step 14850 | Loss: 0.0555 | Spent: 2.6 secs | LR: 0.000140
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.886
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 14900 | Loss: 0.2520 | Spent: 50.2 secs | LR: 0.000140
# INFO:tensorflow:Step 14950 | Loss: 0.5358 | Spent: 2.5 secs | LR: 0.000139
# INFO:tensorflow:Step 15000 | Loss: 0.2081 | Spent: 2.6 secs | LR: 0.000139
# INFO:tensorflow:Step 15050 | Loss: 0.1952 | Spent: 2.5 secs | LR: 0.000139
# INFO:tensorflow:Step 15100 | Loss: 0.3101 | Spent: 2.5 secs | LR: 0.000138
# INFO:tensorflow:Step 15150 | Loss: 0.0912 | Spent: 2.5 secs | LR: 0.000138
# INFO:tensorflow:Step 15200 | Loss: 0.2616 | Spent: 2.6 secs | LR: 0.000138
# INFO:tensorflow:Step 15250 | Loss: 0.2510 | Spent: 2.6 secs | LR: 0.000137
# INFO:tensorflow:Step 15300 | Loss: 0.1460 | Spent: 2.6 secs | LR: 0.000137
# INFO:tensorflow:Step 15350 | Loss: 0.1302 | Spent: 2.5 secs | LR: 0.000137
# INFO:tensorflow:Step 15400 | Loss: 0.5268 | Spent: 2.5 secs | LR: 0.000136
# INFO:tensorflow:Step 15450 | Loss: 0.2745 | Spent: 2.6 secs | LR: 0.000136
# INFO:tensorflow:Step 15500 | Loss: 0.1026 | Spent: 2.6 secs | LR: 0.000135
# INFO:tensorflow:Step 15550 | Loss: 0.0894 | Spent: 2.6 secs | LR: 0.000135
# INFO:tensorflow:Step 15600 | Loss: 0.1533 | Spent: 2.5 secs | LR: 0.000135
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.880
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 15650 | Loss: 0.2452 | Spent: 49.3 secs | LR: 0.000134
# INFO:tensorflow:Step 15700 | Loss: 0.2107 | Spent: 2.6 secs | LR: 0.000134
# INFO:tensorflow:Step 15750 | Loss: 0.1552 | Spent: 2.6 secs | LR: 0.000134
# INFO:tensorflow:Step 15800 | Loss: 0.2820 | Spent: 2.5 secs | LR: 0.000133
# INFO:tensorflow:Step 15850 | Loss: 0.1775 | Spent: 2.5 secs | LR: 0.000133
# INFO:tensorflow:Step 15900 | Loss: 0.1590 | Spent: 2.5 secs | LR: 0.000133
# INFO:tensorflow:Step 15950 | Loss: 0.1937 | Spent: 2.6 secs | LR: 0.000132
# INFO:tensorflow:Step 16000 | Loss: 0.4629 | Spent: 2.6 secs | LR: 0.000132
# INFO:tensorflow:Step 16050 | Loss: 0.3135 | Spent: 2.6 secs | LR: 0.000132
# INFO:tensorflow:Step 16100 | Loss: 0.0554 | Spent: 2.6 secs | LR: 0.000131
# INFO:tensorflow:Step 16150 | Loss: 0.1926 | Spent: 2.5 secs | LR: 0.000131
# INFO:tensorflow:Step 16200 | Loss: 0.2000 | Spent: 2.5 secs | LR: 0.000131
# INFO:tensorflow:Step 16250 | Loss: 0.2549 | Spent: 2.5 secs | LR: 0.000130
# INFO:tensorflow:Step 16300 | Loss: 0.2003 | Spent: 2.5 secs | LR: 0.000130
# INFO:tensorflow:Step 16350 | Loss: 0.1782 | Spent: 2.6 secs | LR: 0.000130
# INFO:tensorflow:Step 16400 | Loss: 0.1372 | Spent: 2.6 secs | LR: 0.000129
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.880
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 16450 | Loss: 0.1700 | Spent: 50.0 secs | LR: 0.000129
# INFO:tensorflow:Step 16500 | Loss: 0.1052 | Spent: 2.5 secs | LR: 0.000129
# INFO:tensorflow:Step 16550 | Loss: 0.2729 | Spent: 2.5 secs | LR: 0.000128
# INFO:tensorflow:Step 16600 | Loss: 0.2221 | Spent: 2.5 secs | LR: 0.000128
# INFO:tensorflow:Step 16650 | Loss: 0.4642 | Spent: 2.6 secs | LR: 0.000128
# INFO:tensorflow:Step 16700 | Loss: 0.1151 | Spent: 2.6 secs | LR: 0.000127
# INFO:tensorflow:Step 16750 | Loss: 0.2325 | Spent: 2.6 secs | LR: 0.000127
# INFO:tensorflow:Step 16800 | Loss: 0.3785 | Spent: 2.5 secs | LR: 0.000127
# INFO:tensorflow:Step 16850 | Loss: 0.2087 | Spent: 2.6 secs | LR: 0.000126
# INFO:tensorflow:Step 16900 | Loss: 0.1002 | Spent: 2.5 secs | LR: 0.000126
# INFO:tensorflow:Step 16950 | Loss: 0.1251 | Spent: 2.5 secs | LR: 0.000126
# INFO:tensorflow:Step 17000 | Loss: 0.1361 | Spent: 2.6 secs | LR: 0.000125
# INFO:tensorflow:Step 17050 | Loss: 0.4205 | Spent: 2.6 secs | LR: 0.000125
# INFO:tensorflow:Step 17100 | Loss: 0.1676 | Spent: 2.6 secs | LR: 0.000125
# INFO:tensorflow:Step 17150 | Loss: 0.1398 | Spent: 2.6 secs | LR: 0.000124
# INFO:tensorflow:Step 17200 | Loss: 0.3052 | Spent: 2.6 secs | LR: 0.000124
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.875
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 17250 | Loss: 0.1061 | Spent: 50.7 secs | LR: 0.000124
# INFO:tensorflow:Step 17300 | Loss: 0.2729 | Spent: 2.5 secs | LR: 0.000124
# INFO:tensorflow:Step 17350 | Loss: 0.2687 | Spent: 2.6 secs | LR: 0.000123
# INFO:tensorflow:Step 17400 | Loss: 0.0927 | Spent: 2.6 secs | LR: 0.000123
# INFO:tensorflow:Step 17450 | Loss: 0.1846 | Spent: 2.5 secs | LR: 0.000123
# INFO:tensorflow:Step 17500 | Loss: 0.0791 | Spent: 2.6 secs | LR: 0.000122
# INFO:tensorflow:Step 17550 | Loss: 0.2210 | Spent: 2.6 secs | LR: 0.000122
# INFO:tensorflow:Step 17600 | Loss: 0.1038 | Spent: 2.5 secs | LR: 0.000122
# INFO:tensorflow:Step 17650 | Loss: 0.3823 | Spent: 2.6 secs | LR: 0.000121
# INFO:tensorflow:Step 17700 | Loss: 0.0479 | Spent: 2.6 secs | LR: 0.000121
# INFO:tensorflow:Step 17750 | Loss: 0.1818 | Spent: 2.6 secs | LR: 0.000121
# INFO:tensorflow:Step 17800 | Loss: 0.0756 | Spent: 2.6 secs | LR: 0.000120
# INFO:tensorflow:Step 17850 | Loss: 0.2073 | Spent: 2.6 secs | LR: 0.000120
# INFO:tensorflow:Step 17900 | Loss: 0.0890 | Spent: 2.5 secs | LR: 0.000120
# INFO:tensorflow:Step 17950 | Loss: 0.1387 | Spent: 2.6 secs | LR: 0.000119
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.876
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 18000 | Loss: 0.2940 | Spent: 50.2 secs | LR: 0.000119
# INFO:tensorflow:Step 18050 | Loss: 0.1015 | Spent: 2.6 secs | LR: 0.000119
# INFO:tensorflow:Step 18100 | Loss: 0.0875 | Spent: 2.5 secs | LR: 0.000119
# INFO:tensorflow:Step 18150 | Loss: 0.0517 | Spent: 2.5 secs | LR: 0.000118
# INFO:tensorflow:Step 18200 | Loss: 0.2180 | Spent: 2.6 secs | LR: 0.000118
# INFO:tensorflow:Step 18250 | Loss: 0.5219 | Spent: 2.5 secs | LR: 0.000118
# INFO:tensorflow:Step 18300 | Loss: 0.2356 | Spent: 2.6 secs | LR: 0.000117
# INFO:tensorflow:Step 18350 | Loss: 0.3013 | Spent: 2.5 secs | LR: 0.000117
# INFO:tensorflow:Step 18400 | Loss: 0.2442 | Spent: 2.6 secs | LR: 0.000117
# INFO:tensorflow:Step 18450 | Loss: 0.0703 | Spent: 2.6 secs | LR: 0.000116
# INFO:tensorflow:Step 18500 | Loss: 0.1455 | Spent: 2.5 secs | LR: 0.000116
# INFO:tensorflow:Step 18550 | Loss: 0.2967 | Spent: 2.6 secs | LR: 0.000116
# INFO:tensorflow:Step 18600 | Loss: 0.1843 | Spent: 2.5 secs | LR: 0.000116
# INFO:tensorflow:Step 18650 | Loss: 0.2973 | Spent: 2.6 secs | LR: 0.000115
# INFO:tensorflow:Step 18700 | Loss: 0.3090 | Spent: 2.5 secs | LR: 0.000115
# INFO:tensorflow:Step 18750 | Loss: 0.1042 | Spent: 2.6 secs | LR: 0.000115
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.882
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 18800 | Loss: 0.2045 | Spent: 49.9 secs | LR: 0.000114
# INFO:tensorflow:Step 18850 | Loss: 0.2757 | Spent: 2.5 secs | LR: 0.000114
# INFO:tensorflow:Step 18900 | Loss: 0.1378 | Spent: 2.6 secs | LR: 0.000114
# INFO:tensorflow:Step 18950 | Loss: 0.3365 | Spent: 2.6 secs | LR: 0.000113
# INFO:tensorflow:Step 19000 | Loss: 0.2376 | Spent: 2.6 secs | LR: 0.000113
# INFO:tensorflow:Step 19050 | Loss: 0.0948 | Spent: 2.6 secs | LR: 0.000113
# INFO:tensorflow:Step 19100 | Loss: 0.2982 | Spent: 2.5 secs | LR: 0.000113
# INFO:tensorflow:Step 19150 | Loss: 0.0985 | Spent: 2.6 secs | LR: 0.000112
# INFO:tensorflow:Step 19200 | Loss: 0.2853 | Spent: 2.5 secs | LR: 0.000112
# INFO:tensorflow:Step 19250 | Loss: 0.4746 | Spent: 2.5 secs | LR: 0.000112
# INFO:tensorflow:Step 19300 | Loss: 0.1675 | Spent: 2.5 secs | LR: 0.000111
# INFO:tensorflow:Step 19350 | Loss: 0.2027 | Spent: 2.6 secs | LR: 0.000111
# INFO:tensorflow:Step 19400 | Loss: 0.3511 | Spent: 2.5 secs | LR: 0.000111
# INFO:tensorflow:Step 19450 | Loss: 0.1495 | Spent: 2.5 secs | LR: 0.000111
# INFO:tensorflow:Step 19500 | Loss: 0.1123 | Spent: 2.5 secs | LR: 0.000110
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 19550 | Loss: 0.3833 | Spent: 50.4 secs | LR: 0.000110
# INFO:tensorflow:Step 19600 | Loss: 0.1694 | Spent: 2.6 secs | LR: 0.000110
# INFO:tensorflow:Step 19650 | Loss: 0.0939 | Spent: 2.6 secs | LR: 0.000109
# INFO:tensorflow:Step 19700 | Loss: 0.1166 | Spent: 2.6 secs | LR: 0.000109
# INFO:tensorflow:Step 19750 | Loss: 0.2343 | Spent: 2.5 secs | LR: 0.000109
# INFO:tensorflow:Step 19800 | Loss: 0.0919 | Spent: 2.5 secs | LR: 0.000109
# INFO:tensorflow:Step 19850 | Loss: 0.3761 | Spent: 2.6 secs | LR: 0.000108
# INFO:tensorflow:Step 19900 | Loss: 0.1392 | Spent: 2.6 secs | LR: 0.000108
# INFO:tensorflow:Step 19950 | Loss: 0.1584 | Spent: 2.6 secs | LR: 0.000108
# INFO:tensorflow:Step 20000 | Loss: 0.0590 | Spent: 2.6 secs | LR: 0.000108
# INFO:tensorflow:Step 20050 | Loss: 0.1698 | Spent: 2.6 secs | LR: 0.000107
# INFO:tensorflow:Step 20100 | Loss: 0.2231 | Spent: 2.6 secs | LR: 0.000107
# INFO:tensorflow:Step 20150 | Loss: 0.2345 | Spent: 2.6 secs | LR: 0.000107
# INFO:tensorflow:Step 20200 | Loss: 0.2075 | Spent: 2.6 secs | LR: 0.000106
# INFO:tensorflow:Step 20250 | Loss: 0.5202 | Spent: 2.6 secs | LR: 0.000106
# INFO:tensorflow:Step 20300 | Loss: 0.0938 | Spent: 2.6 secs | LR: 0.000106
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.882
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 20350 | Loss: 0.1111 | Spent: 50.0 secs | LR: 0.000106
# INFO:tensorflow:Step 20400 | Loss: 0.2058 | Spent: 2.5 secs | LR: 0.000105
# INFO:tensorflow:Step 20450 | Loss: 0.2697 | Spent: 2.6 secs | LR: 0.000105
# INFO:tensorflow:Step 20500 | Loss: 0.0901 | Spent: 2.6 secs | LR: 0.000105
# INFO:tensorflow:Step 20550 | Loss: 0.2508 | Spent: 2.6 secs | LR: 0.000105
# INFO:tensorflow:Step 20600 | Loss: 0.4280 | Spent: 2.6 secs | LR: 0.000104
# INFO:tensorflow:Step 20650 | Loss: 0.3437 | Spent: 2.5 secs | LR: 0.000104
# INFO:tensorflow:Step 20700 | Loss: 0.0726 | Spent: 2.6 secs | LR: 0.000104
# INFO:tensorflow:Step 20750 | Loss: 0.1154 | Spent: 2.6 secs | LR: 0.000103
# INFO:tensorflow:Step 20800 | Loss: 0.0648 | Spent: 2.6 secs | LR: 0.000103
# INFO:tensorflow:Step 20850 | Loss: 0.2827 | Spent: 2.6 secs | LR: 0.000103
# INFO:tensorflow:Step 20900 | Loss: 0.3178 | Spent: 2.6 secs | LR: 0.000103
# INFO:tensorflow:Step 20950 | Loss: 0.1295 | Spent: 2.6 secs | LR: 0.000102
# INFO:tensorflow:Step 21000 | Loss: 0.1047 | Spent: 2.6 secs | LR: 0.000102
# INFO:tensorflow:Step 21050 | Loss: 0.1219 | Spent: 2.6 secs | LR: 0.000102
# INFO:tensorflow:Step 21100 | Loss: 0.1932 | Spent: 2.5 secs | LR: 0.000102
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.885
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 21150 | Loss: 0.0792 | Spent: 50.2 secs | LR: 0.000101
# INFO:tensorflow:Step 21200 | Loss: 0.1228 | Spent: 2.5 secs | LR: 0.000101
# INFO:tensorflow:Step 21250 | Loss: 0.2365 | Spent: 2.6 secs | LR: 0.000101
# INFO:tensorflow:Step 21300 | Loss: 0.1429 | Spent: 2.6 secs | LR: 0.000101
# INFO:tensorflow:Step 21350 | Loss: 0.1970 | Spent: 2.6 secs | LR: 0.000100
# INFO:tensorflow:Step 21400 | Loss: 0.1434 | Spent: 2.6 secs | LR: 0.000100
# INFO:tensorflow:Step 21450 | Loss: 0.1182 | Spent: 2.6 secs | LR: 0.000100
# INFO:tensorflow:Step 21500 | Loss: 0.1581 | Spent: 2.6 secs | LR: 0.000100
# INFO:tensorflow:Step 21550 | Loss: 0.0682 | Spent: 2.6 secs | LR: 0.000099
# INFO:tensorflow:Step 21600 | Loss: 0.1142 | Spent: 2.6 secs | LR: 0.000099
# INFO:tensorflow:Step 21650 | Loss: 0.1040 | Spent: 2.5 secs | LR: 0.000099
# INFO:tensorflow:Step 21700 | Loss: 0.0513 | Spent: 2.6 secs | LR: 0.000099
# INFO:tensorflow:Step 21750 | Loss: 0.1957 | Spent: 2.6 secs | LR: 0.000098
# INFO:tensorflow:Step 21800 | Loss: 0.3951 | Spent: 2.6 secs | LR: 0.000098
# INFO:tensorflow:Step 21850 | Loss: 0.1507 | Spent: 2.6 secs | LR: 0.000098
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.880
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 21900 | Loss: 0.1153 | Spent: 50.5 secs | LR: 0.000098
# INFO:tensorflow:Step 21950 | Loss: 0.0790 | Spent: 2.5 secs | LR: 0.000097
# INFO:tensorflow:Step 22000 | Loss: 0.1189 | Spent: 2.5 secs | LR: 0.000097
# INFO:tensorflow:Step 22050 | Loss: 0.0902 | Spent: 2.5 secs | LR: 0.000097
# INFO:tensorflow:Step 22100 | Loss: 0.2106 | Spent: 2.6 secs | LR: 0.000097
# INFO:tensorflow:Step 22150 | Loss: 0.0661 | Spent: 2.6 secs | LR: 0.000096
# INFO:tensorflow:Step 22200 | Loss: 0.3064 | Spent: 2.5 secs | LR: 0.000096
# INFO:tensorflow:Step 22250 | Loss: 0.0697 | Spent: 2.6 secs | LR: 0.000096
# INFO:tensorflow:Step 22300 | Loss: 0.2339 | Spent: 2.6 secs | LR: 0.000096
# INFO:tensorflow:Step 22350 | Loss: 0.1056 | Spent: 2.5 secs | LR: 0.000095
# INFO:tensorflow:Step 22400 | Loss: 0.0975 | Spent: 2.5 secs | LR: 0.000095
# INFO:tensorflow:Step 22450 | Loss: 0.1608 | Spent: 2.6 secs | LR: 0.000095
# INFO:tensorflow:Step 22500 | Loss: 0.1110 | Spent: 2.6 secs | LR: 0.000095
# INFO:tensorflow:Step 22550 | Loss: 0.1624 | Spent: 2.5 secs | LR: 0.000094
# INFO:tensorflow:Step 22600 | Loss: 0.1324 | Spent: 2.5 secs | LR: 0.000094
# INFO:tensorflow:Step 22650 | Loss: 0.1559 | Spent: 2.6 secs | LR: 0.000094
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.885
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 22700 | Loss: 0.1565 | Spent: 50.1 secs | LR: 0.000094
# INFO:tensorflow:Step 22750 | Loss: 0.1121 | Spent: 2.6 secs | LR: 0.000093
# INFO:tensorflow:Step 22800 | Loss: 0.2683 | Spent: 2.5 secs | LR: 0.000093
# INFO:tensorflow:Step 22850 | Loss: 0.1040 | Spent: 2.6 secs | LR: 0.000093
# INFO:tensorflow:Step 22900 | Loss: 0.0376 | Spent: 2.6 secs | LR: 0.000093
# INFO:tensorflow:Step 22950 | Loss: 0.1595 | Spent: 2.6 secs | LR: 0.000092
# INFO:tensorflow:Step 23000 | Loss: 0.1876 | Spent: 2.6 secs | LR: 0.000092
# INFO:tensorflow:Step 23050 | Loss: 0.1692 | Spent: 2.6 secs | LR: 0.000092
# INFO:tensorflow:Step 23100 | Loss: 0.0807 | Spent: 2.6 secs | LR: 0.000092
# INFO:tensorflow:Step 23150 | Loss: 0.0656 | Spent: 2.6 secs | LR: 0.000092
# INFO:tensorflow:Step 23200 | Loss: 0.2318 | Spent: 2.6 secs | LR: 0.000091
# INFO:tensorflow:Step 23250 | Loss: 0.0839 | Spent: 2.6 secs | LR: 0.000091
# INFO:tensorflow:Step 23300 | Loss: 0.0797 | Spent: 2.5 secs | LR: 0.000091
# INFO:tensorflow:Step 23350 | Loss: 0.0385 | Spent: 2.6 secs | LR: 0.000091
# INFO:tensorflow:Step 23400 | Loss: 0.1503 | Spent: 2.6 secs | LR: 0.000090
# INFO:tensorflow:Step 23450 | Loss: 0.1544 | Spent: 2.6 secs | LR: 0.000090
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.878
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 23500 | Loss: 0.3748 | Spent: 49.7 secs | LR: 0.000090
# INFO:tensorflow:Step 23550 | Loss: 0.0902 | Spent: 2.5 secs | LR: 0.000090
# INFO:tensorflow:Step 23600 | Loss: 0.0410 | Spent: 2.5 secs | LR: 0.000089
# INFO:tensorflow:Step 23650 | Loss: 0.0476 | Spent: 2.6 secs | LR: 0.000089
# INFO:tensorflow:Step 23700 | Loss: 0.3459 | Spent: 2.6 secs | LR: 0.000089
# INFO:tensorflow:Step 23750 | Loss: 0.0520 | Spent: 2.6 secs | LR: 0.000089
# INFO:tensorflow:Step 23800 | Loss: 0.1811 | Spent: 2.6 secs | LR: 0.000088
# INFO:tensorflow:Step 23850 | Loss: 0.1254 | Spent: 2.6 secs | LR: 0.000088
# INFO:tensorflow:Step 23900 | Loss: 0.0735 | Spent: 2.6 secs | LR: 0.000088
# INFO:tensorflow:Step 23950 | Loss: 0.0941 | Spent: 2.6 secs | LR: 0.000088
# INFO:tensorflow:Step 24000 | Loss: 0.2967 | Spent: 2.6 secs | LR: 0.000088
# INFO:tensorflow:Step 24050 | Loss: 0.1882 | Spent: 2.6 secs | LR: 0.000087
# INFO:tensorflow:Step 24100 | Loss: 0.2017 | Spent: 2.6 secs | LR: 0.000087
# INFO:tensorflow:Step 24150 | Loss: 0.2668 | Spent: 2.6 secs | LR: 0.000087
# INFO:tensorflow:Step 24200 | Loss: 0.0822 | Spent: 2.6 secs | LR: 0.000087
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.877
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 24250 | Loss: 0.3105 | Spent: 49.8 secs | LR: 0.000086
# INFO:tensorflow:Step 24300 | Loss: 0.0815 | Spent: 2.5 secs | LR: 0.000086
# INFO:tensorflow:Step 24350 | Loss: 0.0741 | Spent: 2.5 secs | LR: 0.000086
# INFO:tensorflow:Step 24400 | Loss: 0.2094 | Spent: 2.5 secs | LR: 0.000086
# INFO:tensorflow:Step 24450 | Loss: 0.1198 | Spent: 2.6 secs | LR: 0.000086
# INFO:tensorflow:Step 24500 | Loss: 0.3199 | Spent: 2.6 secs | LR: 0.000085
# INFO:tensorflow:Step 24550 | Loss: 0.1675 | Spent: 2.6 secs | LR: 0.000085
# INFO:tensorflow:Step 24600 | Loss: 0.3448 | Spent: 2.5 secs | LR: 0.000085
# INFO:tensorflow:Step 24650 | Loss: 0.1904 | Spent: 2.6 secs | LR: 0.000085
# INFO:tensorflow:Step 24700 | Loss: 0.0720 | Spent: 2.6 secs | LR: 0.000085
# INFO:tensorflow:Step 24750 | Loss: 0.1034 | Spent: 2.6 secs | LR: 0.000084
# INFO:tensorflow:Step 24800 | Loss: 0.2089 | Spent: 2.6 secs | LR: 0.000084
# INFO:tensorflow:Step 24850 | Loss: 0.0669 | Spent: 2.6 secs | LR: 0.000084
# INFO:tensorflow:Step 24900 | Loss: 0.1883 | Spent: 2.5 secs | LR: 0.000084
# INFO:tensorflow:Step 24950 | Loss: 0.0478 | Spent: 2.5 secs | LR: 0.000083
# INFO:tensorflow:Step 25000 | Loss: 0.2683 | Spent: 2.5 secs | LR: 0.000083
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.882
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 25050 | Loss: 0.1364 | Spent: 50.5 secs | LR: 0.000083
# INFO:tensorflow:Step 25100 | Loss: 0.0745 | Spent: 2.5 secs | LR: 0.000083
# INFO:tensorflow:Step 25150 | Loss: 0.0546 | Spent: 2.5 secs | LR: 0.000083
# INFO:tensorflow:Step 25200 | Loss: 0.2111 | Spent: 2.6 secs | LR: 0.000082
# INFO:tensorflow:Step 25250 | Loss: 0.2092 | Spent: 2.6 secs | LR: 0.000082
# INFO:tensorflow:Step 25300 | Loss: 0.2179 | Spent: 2.5 secs | LR: 0.000082
# INFO:tensorflow:Step 25350 | Loss: 0.0699 | Spent: 2.5 secs | LR: 0.000082
# INFO:tensorflow:Step 25400 | Loss: 0.0861 | Spent: 2.6 secs | LR: 0.000082
# INFO:tensorflow:Step 25450 | Loss: 0.3298 | Spent: 2.5 secs | LR: 0.000081
# INFO:tensorflow:Step 25500 | Loss: 0.0808 | Spent: 2.5 secs | LR: 0.000081
# INFO:tensorflow:Step 25550 | Loss: 0.1021 | Spent: 2.5 secs | LR: 0.000081
# INFO:tensorflow:Step 25600 | Loss: 0.2114 | Spent: 2.5 secs | LR: 0.000081
# INFO:tensorflow:Step 25650 | Loss: 0.3129 | Spent: 2.5 secs | LR: 0.000080
# INFO:tensorflow:Step 25700 | Loss: 0.0665 | Spent: 2.6 secs | LR: 0.000080
# INFO:tensorflow:Step 25750 | Loss: 0.1322 | Spent: 2.5 secs | LR: 0.000080
# INFO:tensorflow:Step 25800 | Loss: 0.0491 | Spent: 2.6 secs | LR: 0.000080
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 25850 | Loss: 0.0489 | Spent: 50.5 secs | LR: 0.000080
# INFO:tensorflow:Step 25900 | Loss: 0.1987 | Spent: 2.5 secs | LR: 0.000079
# INFO:tensorflow:Step 25950 | Loss: 0.0960 | Spent: 2.5 secs | LR: 0.000079
# INFO:tensorflow:Step 26000 | Loss: 0.1713 | Spent: 2.5 secs | LR: 0.000079
# INFO:tensorflow:Step 26050 | Loss: 0.1763 | Spent: 2.5 secs | LR: 0.000079
# INFO:tensorflow:Step 26100 | Loss: 0.1415 | Spent: 2.5 secs | LR: 0.000079
# INFO:tensorflow:Step 26150 | Loss: 0.0823 | Spent: 2.5 secs | LR: 0.000078
# INFO:tensorflow:Step 26200 | Loss: 0.1302 | Spent: 2.5 secs | LR: 0.000078
# INFO:tensorflow:Step 26250 | Loss: 0.0592 | Spent: 2.5 secs | LR: 0.000078
# INFO:tensorflow:Step 26300 | Loss: 0.1393 | Spent: 2.5 secs | LR: 0.000078
# INFO:tensorflow:Step 26350 | Loss: 0.0623 | Spent: 2.6 secs | LR: 0.000078
# INFO:tensorflow:Step 26400 | Loss: 0.1363 | Spent: 2.5 secs | LR: 0.000077
# INFO:tensorflow:Step 26450 | Loss: 0.1299 | Spent: 2.6 secs | LR: 0.000077
# INFO:tensorflow:Step 26500 | Loss: 0.0410 | Spent: 2.6 secs | LR: 0.000077
# INFO:tensorflow:Step 26550 | Loss: 0.1340 | Spent: 2.6 secs | LR: 0.000077
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.879
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 26600 | Loss: 0.1519 | Spent: 51.0 secs | LR: 0.000077
# INFO:tensorflow:Step 26650 | Loss: 0.3006 | Spent: 2.6 secs | LR: 0.000076
# INFO:tensorflow:Step 26700 | Loss: 0.1084 | Spent: 2.6 secs | LR: 0.000076
# INFO:tensorflow:Step 26750 | Loss: 0.1358 | Spent: 2.6 secs | LR: 0.000076
# INFO:tensorflow:Step 26800 | Loss: 0.0442 | Spent: 2.6 secs | LR: 0.000076
# INFO:tensorflow:Step 26850 | Loss: 0.1281 | Spent: 2.6 secs | LR: 0.000076
# INFO:tensorflow:Step 26900 | Loss: 0.1948 | Spent: 2.6 secs | LR: 0.000075
# INFO:tensorflow:Step 26950 | Loss: 0.0985 | Spent: 2.6 secs | LR: 0.000075
# INFO:tensorflow:Step 27000 | Loss: 0.1150 | Spent: 2.6 secs | LR: 0.000075
# INFO:tensorflow:Step 27050 | Loss: 0.0466 | Spent: 2.6 secs | LR: 0.000075
# INFO:tensorflow:Step 27100 | Loss: 0.1553 | Spent: 2.6 secs | LR: 0.000075
# INFO:tensorflow:Step 27150 | Loss: 0.1054 | Spent: 2.6 secs | LR: 0.000075
# INFO:tensorflow:Step 27200 | Loss: 0.0684 | Spent: 2.6 secs | LR: 0.000074
# INFO:tensorflow:Step 27250 | Loss: 0.0585 | Spent: 2.6 secs | LR: 0.000074
# INFO:tensorflow:Step 27300 | Loss: 0.1109 | Spent: 2.5 secs | LR: 0.000074
# INFO:tensorflow:Step 27350 | Loss: 0.0958 | Spent: 2.6 secs | LR: 0.000074
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.885
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 27400 | Loss: 0.0810 | Spent: 50.5 secs | LR: 0.000074
# INFO:tensorflow:Step 27450 | Loss: 0.0478 | Spent: 2.5 secs | LR: 0.000073
# INFO:tensorflow:Step 27500 | Loss: 0.1013 | Spent: 2.6 secs | LR: 0.000073
# INFO:tensorflow:Step 27550 | Loss: 0.1441 | Spent: 2.6 secs | LR: 0.000073
# INFO:tensorflow:Step 27600 | Loss: 0.1509 | Spent: 2.6 secs | LR: 0.000073
# INFO:tensorflow:Step 27650 | Loss: 0.1121 | Spent: 2.5 secs | LR: 0.000073
# INFO:tensorflow:Step 27700 | Loss: 0.1703 | Spent: 2.6 secs | LR: 0.000072
# INFO:tensorflow:Step 27750 | Loss: 0.1476 | Spent: 2.6 secs | LR: 0.000072
# INFO:tensorflow:Step 27800 | Loss: 0.0892 | Spent: 2.5 secs | LR: 0.000072
# INFO:tensorflow:Step 27850 | Loss: 0.0307 | Spent: 2.6 secs | LR: 0.000072
# INFO:tensorflow:Step 27900 | Loss: 0.2880 | Spent: 2.6 secs | LR: 0.000072
# INFO:tensorflow:Step 27950 | Loss: 0.1063 | Spent: 2.6 secs | LR: 0.000072
# INFO:tensorflow:Step 28000 | Loss: 0.1799 | Spent: 2.6 secs | LR: 0.000071
# INFO:tensorflow:Step 28050 | Loss: 0.0936 | Spent: 2.5 secs | LR: 0.000071
# INFO:tensorflow:Step 28100 | Loss: 0.0649 | Spent: 2.6 secs | LR: 0.000071
# INFO:tensorflow:Step 28150 | Loss: 0.1071 | Spent: 2.6 secs | LR: 0.000071
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 28200 | Loss: 0.0523 | Spent: 50.1 secs | LR: 0.000071
# INFO:tensorflow:Step 28250 | Loss: 0.0406 | Spent: 2.5 secs | LR: 0.000070
# INFO:tensorflow:Step 28300 | Loss: 0.1350 | Spent: 2.5 secs | LR: 0.000070
# INFO:tensorflow:Step 28350 | Loss: 0.0576 | Spent: 2.5 secs | LR: 0.000070
# INFO:tensorflow:Step 28400 | Loss: 0.2350 | Spent: 2.6 secs | LR: 0.000070
# INFO:tensorflow:Step 28450 | Loss: 0.0920 | Spent: 2.6 secs | LR: 0.000070
# INFO:tensorflow:Step 28500 | Loss: 0.0656 | Spent: 2.6 secs | LR: 0.000070
# INFO:tensorflow:Step 28550 | Loss: 0.1347 | Spent: 2.6 secs | LR: 0.000069
# INFO:tensorflow:Step 28600 | Loss: 0.1215 | Spent: 2.5 secs | LR: 0.000069
# INFO:tensorflow:Step 28650 | Loss: 0.3714 | Spent: 2.6 secs | LR: 0.000069
# INFO:tensorflow:Step 28700 | Loss: 0.2768 | Spent: 2.6 secs | LR: 0.000069
# INFO:tensorflow:Step 28750 | Loss: 0.0678 | Spent: 2.6 secs | LR: 0.000069
# INFO:tensorflow:Step 28800 | Loss: 0.0410 | Spent: 2.6 secs | LR: 0.000068
# INFO:tensorflow:Step 28850 | Loss: 0.1789 | Spent: 2.6 secs | LR: 0.000068
# INFO:tensorflow:Step 28900 | Loss: 0.0897 | Spent: 2.6 secs | LR: 0.000068
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 28950 | Loss: 0.0673 | Spent: 50.5 secs | LR: 0.000068
# INFO:tensorflow:Step 29000 | Loss: 0.1098 | Spent: 2.6 secs | LR: 0.000068
# INFO:tensorflow:Step 29050 | Loss: 0.0924 | Spent: 2.6 secs | LR: 0.000068
# INFO:tensorflow:Step 29100 | Loss: 0.2910 | Spent: 2.6 secs | LR: 0.000067
# INFO:tensorflow:Step 29150 | Loss: 0.0680 | Spent: 2.6 secs | LR: 0.000067
# INFO:tensorflow:Step 29200 | Loss: 0.0700 | Spent: 2.6 secs | LR: 0.000067
# INFO:tensorflow:Step 29250 | Loss: 0.0643 | Spent: 2.6 secs | LR: 0.000067
# INFO:tensorflow:Step 29300 | Loss: 0.0315 | Spent: 2.7 secs | LR: 0.000067
# INFO:tensorflow:Step 29350 | Loss: 0.1933 | Spent: 2.6 secs | LR: 0.000067
# INFO:tensorflow:Step 29400 | Loss: 0.0635 | Spent: 2.6 secs | LR: 0.000066
# INFO:tensorflow:Step 29450 | Loss: 0.1218 | Spent: 2.6 secs | LR: 0.000066
# INFO:tensorflow:Step 29500 | Loss: 0.1201 | Spent: 2.6 secs | LR: 0.000066
# INFO:tensorflow:Step 29550 | Loss: 0.2288 | Spent: 2.6 secs | LR: 0.000066
# INFO:tensorflow:Step 29600 | Loss: 0.2251 | Spent: 2.6 secs | LR: 0.000066
# INFO:tensorflow:Step 29650 | Loss: 0.0604 | Spent: 2.6 secs | LR: 0.000066
# INFO:tensorflow:Step 29700 | Loss: 0.0802 | Spent: 2.6 secs | LR: 0.000065
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 29750 | Loss: 0.0660 | Spent: 50.4 secs | LR: 0.000065
# INFO:tensorflow:Step 29800 | Loss: 0.0388 | Spent: 2.6 secs | LR: 0.000065
# INFO:tensorflow:Step 29850 | Loss: 0.0684 | Spent: 2.6 secs | LR: 0.000065
# INFO:tensorflow:Step 29900 | Loss: 0.2307 | Spent: 2.6 secs | LR: 0.000065
# INFO:tensorflow:Step 29950 | Loss: 0.1091 | Spent: 2.6 secs | LR: 0.000065
# INFO:tensorflow:Step 30000 | Loss: 0.0531 | Spent: 2.6 secs | LR: 0.000064
# INFO:tensorflow:Step 30050 | Loss: 0.0893 | Spent: 2.6 secs | LR: 0.000064
# INFO:tensorflow:Step 30100 | Loss: 0.0871 | Spent: 2.6 secs | LR: 0.000064
# INFO:tensorflow:Step 30150 | Loss: 0.1861 | Spent: 2.6 secs | LR: 0.000064
# INFO:tensorflow:Step 30200 | Loss: 0.1856 | Spent: 2.6 secs | LR: 0.000064
# INFO:tensorflow:Step 30250 | Loss: 0.0344 | Spent: 2.6 secs | LR: 0.000064
# INFO:tensorflow:Step 30300 | Loss: 0.1055 | Spent: 2.6 secs | LR: 0.000063
# INFO:tensorflow:Step 30350 | Loss: 0.0928 | Spent: 2.6 secs | LR: 0.000063
# INFO:tensorflow:Step 30400 | Loss: 0.1032 | Spent: 2.6 secs | LR: 0.000063
# INFO:tensorflow:Step 30450 | Loss: 0.0932 | Spent: 2.6 secs | LR: 0.000063
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.883
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 30500 | Loss: 0.1262 | Spent: 50.3 secs | LR: 0.000063
# INFO:tensorflow:Step 30550 | Loss: 0.1507 | Spent: 2.6 secs | LR: 0.000063
# INFO:tensorflow:Step 30600 | Loss: 0.2364 | Spent: 2.5 secs | LR: 0.000062
# INFO:tensorflow:Step 30650 | Loss: 0.0297 | Spent: 2.5 secs | LR: 0.000062
# INFO:tensorflow:Step 30700 | Loss: 0.2243 | Spent: 2.6 secs | LR: 0.000062
# INFO:tensorflow:Step 30750 | Loss: 0.1408 | Spent: 2.6 secs | LR: 0.000062
# INFO:tensorflow:Step 30800 | Loss: 0.0686 | Spent: 2.5 secs | LR: 0.000062
# INFO:tensorflow:Step 30850 | Loss: 0.3860 | Spent: 2.6 secs | LR: 0.000062
# INFO:tensorflow:Step 30900 | Loss: 0.0515 | Spent: 2.6 secs | LR: 0.000061
# INFO:tensorflow:Step 30950 | Loss: 0.1132 | Spent: 2.5 secs | LR: 0.000061
# INFO:tensorflow:Step 31000 | Loss: 0.0453 | Spent: 2.6 secs | LR: 0.000061
# INFO:tensorflow:Step 31050 | Loss: 0.1430 | Spent: 2.5 secs | LR: 0.000061
# INFO:tensorflow:Step 31100 | Loss: 0.3143 | Spent: 2.6 secs | LR: 0.000061
# INFO:tensorflow:Step 31150 | Loss: 0.1826 | Spent: 2.6 secs | LR: 0.000061
# INFO:tensorflow:Step 31200 | Loss: 0.0806 | Spent: 2.6 secs | LR: 0.000061
# INFO:tensorflow:Step 31250 | Loss: 0.1427 | Spent: 2.6 secs | LR: 0.000060
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.883
# INFO:tensorflow:Best Accuracy: 0.886
# Reading ./data/train.txt
# INFO:tensorflow:Step 31300 | Loss: 0.1153 | Spent: 49.8 secs | LR: 0.000060
# INFO:tensorflow:Step 31350 | Loss: 0.1124 | Spent: 2.5 secs | LR: 0.000060
# INFO:tensorflow:Step 31400 | Loss: 0.1394 | Spent: 2.5 secs | LR: 0.000060
# INFO:tensorflow:Step 31450 | Loss: 0.0446 | Spent: 2.6 secs | LR: 0.000060
# INFO:tensorflow:Step 31500 | Loss: 0.0308 | Spent: 2.6 secs | LR: 0.000060
# INFO:tensorflow:Step 31550 | Loss: 0.0934 | Spent: 2.5 secs | LR: 0.000059
# INFO:tensorflow:Step 31600 | Loss: 0.2211 | Spent: 2.6 secs | LR: 0.000059
# INFO:tensorflow:Step 31650 | Loss: 0.0498 | Spent: 2.6 secs | LR: 0.000059
# INFO:tensorflow:Step 31700 | Loss: 0.0549 | Spent: 2.5 secs | LR: 0.000059
# INFO:tensorflow:Step 31750 | Loss: 0.1048 | Spent: 2.5 secs | LR: 0.000059
# INFO:tensorflow:Step 31800 | Loss: 0.2011 | Spent: 2.5 secs | LR: 0.000059
# INFO:tensorflow:Step 31850 | Loss: 0.0476 | Spent: 2.6 secs | LR: 0.000059
# INFO:tensorflow:Step 31900 | Loss: 0.0932 | Spent: 2.6 secs | LR: 0.000058
# INFO:tensorflow:Step 31950 | Loss: 0.0739 | Spent: 2.6 secs | LR: 0.000058
# INFO:tensorflow:Step 32000 | Loss: 0.1327 | Spent: 2.6 secs | LR: 0.000058
# INFO:tensorflow:Step 32050 | Loss: 0.0627 | Spent: 2.6 secs | LR: 0.000058
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.879
# INFO:tensorflow:Best Accuracy: 0.886
# INFO:tensorflow:Testing Accuracy not improved over 3 epochs, Early Stop
